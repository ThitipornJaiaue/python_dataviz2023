# %% [markdown]
# <a href="https://colab.research.google.com/github/ThitipornJaiaue/python_dataviz2023/blob/main/Pandas101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Meta data = Data that describtion data
#
# ใช้อธิบายช้อมูล
#
# ## CSV = Comma Separated Values
# ในการจะใส่ค่าแต่ละค่า จะใช้  comma ในการแย่ง

# %% [markdown]
# .csv = Comma Separated Values

# %% [markdown]
# data.go.th

# %% [markdown]
# # นำ Data เข้า
# - upload to colab  # กรณีใช้เเค่ครั้งเดียว
# - link with google drive

# %% [markdown]
# ## upload to colab

# %%
data0 = pd.read_csv('/content/drive/MyDrive/DataViz23Data/csv (1).csv')

# %%
#data0

# %%
data0.head()
# Out:
#   Budget_resource  Issue_No  Fiscal_year  Department_code        Department  \
# 0       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 1       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 2       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 3       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 4       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
#
#                                     Core_budget_code Expenditure_category  \
# 0  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 1  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 2  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 3  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 4  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
#
#                                            Item_name  Approved_buget
# 0        ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ         1193000
# 1  ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคช...         1100000
# 2          ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข         3075000
# 3  ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำ...         6240000
# 4  ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุ...         2685000

# %% [markdown]
# ## link with google drive

# %%
from google.colab import drive
drive.mount('/content/drive')  # mount =  เชื่อมไดร์ฟ
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data1 = pd.read_csv('/content/drive/MyDrive/DataViz23Data/csv (1).csv')
data1.head()
# Out:
#   Budget_resource  Issue_No  Fiscal_year  Department_code        Department  \
# 0       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 1       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 2       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 3       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 4       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
#
#                                     Core_budget_code Expenditure_category  \
# 0  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 1  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 2  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 3  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 4  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
#
#                                            Item_name  Approved_buget
# 0        ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ         1193000
# 1  ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคช...         1100000
# 2          ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข         3075000
# 3  ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำ...         6240000
# 4  ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุ...         2685000

# %%
data1.head(10)  # ดูหัวตาราง จากแถวบน 10 แถวแรก นับจาก 0-9
# Out:
#   Budget_resource  Issue_No  Fiscal_year  Department_code          Department  \
# 0       งบประจำปี         0           62         11000000    สำนักการระบายน้ำ
# 1       งบประจำปี         0           62         11000000    สำนักการระบายน้ำ
# 2       งบประจำปี         0           62         11000000    สำนักการระบายน้ำ
# 3       งบประจำปี         0           62         11000000    สำนักการระบายน้ำ
# 4       งบประจำปี         0           62         11000000    สำนักการระบายน้ำ
# 5       งบประจำปี         0           62         11000000    สำนักการระบายน้ำ
# 6       งบประจำปี         0           62         50130000  สำนักงานเขตมีนบุรี
# 7       งบประจำปี         0           62         50130000  สำนักงานเขตมีนบุรี
# 8       งบประจำปี         0           62         50150000  สำนักงานเขตหนองจอก
# 9       งบประจำปี         0           62         50150000  สำนักงานเขตหนองจอก
#
#                                     Core_budget_code Expenditure_category  \
# 0  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 1  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 2  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 3  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 4  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 5  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 6  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 7  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 8               28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต              งบลงทุน
# 9               28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต              งบลงทุน
#
#                                            Item_name  Approved_buget
# 0        ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ         1193000
# 1  ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคช...         1100000
# 2          ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข         3075000
# 3  ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำ...         6240000
# 4  ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุ...         2685000
# 5  ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองม...         1207000
# 6  ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระย...          225400
# 7  ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวาง...          452500
# 8  ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเ...          447000
# 9  ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำม...          497000

# %%
data1.tail(10) # ดูท้ายตาราง จากข้างล่าง
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 682     งบเพิ่มเติม         1           66         50460000
# 683     งบเพิ่มเติม         1           66         50460000
# 684     งบเพิ่มเติม         1           66         50460000
# 685     งบเพิ่มเติม         1           66         50460000
# 686     งบเพิ่มเติม         1           66         50460000
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Core_budget_code Expenditure_category  \
# 682  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 683  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 684  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 685  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 686  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 691     สำนักงานเขตบางบอน              NaN              งบลงทุน
#
#                                      Item_name  Approved_buget
# 682                      ขุดลอกลำรางไทยเอราวัณ         3494000
# 683                     ขุดลอกคลองหนึ่งตะวันตก         4330000
# 684                       ขุดลอกคลองสองตะวันตก         9832000
# 685                           ขุดลอกคลองกีบหมู         2925000
# 686                         ขุดลอกคลองลำกะโหลก         3875000
# 687                         ขุดลอกคลองผักกะเฉด         3686000
# 688                    ขุดลอกคลองบึงทรายกองดิน         2575000
# 689                          ขุดลอกลำรางซาฟารี          689000
# 690                        ขุดลอกลำรางตาจันทร์          464000
# 691  ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล         7578000

# %%
data1.shape # ดูขนาด กี่เเถวกี่หลัก
# Out:
# (692, 9)

# %%
data1.describe()
# Out:
#          Issue_No  Fiscal_year  Department_code  Approved_buget
# count  692.000000   692.000000     6.920000e+02    6.920000e+02
# mean     0.333815    64.543353     4.534202e+07    1.482811e+06
# std      0.474972     1.476149     1.303279e+07    2.464625e+06
# min      0.000000    62.000000     1.100000e+07    0.000000e+00
# 25%      0.000000    63.000000     5.013000e+07    4.100000e+05
# 50%      0.000000    65.000000     5.023000e+07    5.980000e+05
# 75%      1.000000    66.000000     5.036000e+07    1.628250e+06
# max      2.000000    66.000000     5.050000e+07    2.850000e+07

# %% [markdown]
# NaN = Not a Number

# %% [markdown]
# -------load data into pandas---24july23--------

# %% [markdown]
# DF คือ DataFlame เป็นชื่อ Data tructure ที่ Pandas ใช้

# %% [markdown]
# # ชี้ค่าในตาราง (indexing)

# %% [markdown]
# ## มุมมองตาราง df[columns][rows]

# %%
data1['Budget_resource']
# Out:
# 0        งบประจำปี
# 1        งบประจำปี
# 2        งบประจำปี
# 3        งบประจำปี
# 4        งบประจำปี
#           ...
# 687    งบเพิ่มเติม
# 688    งบเพิ่มเติม
# 689    งบเพิ่มเติม
# 690    งบเพิ่มเติม
# 691    งบเพิ่มเติม
# Name: Budget_resource, Length: 692, dtype: object

# %%
data1['Budget_resource'][690]
# Out:
# 'งบเพิ่มเติม'

# %%
data1['Budget_resource'][-3:-1]
# Out:
# 689    งบเพิ่มเติม
# 690    งบเพิ่มเติม
# Name: Budget_resource, dtype: object

# %%
data1.columns
# Out:
# Index(['Budget_resource', 'Issue_No', 'Fiscal_year', 'Department_code',
#        'Department', 'Core_budget_code', 'Expenditure_category', 'Item_name',
#        'Approved_buget'],
#       dtype='object')

# %%
data1[['Approved_buget','Item_name', 'Department']]
# Out:
#      Approved_buget                                          Item_name  \
# 0           1193000        ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ
# 1           1100000  ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคช...
# 2           3075000          ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข
# 3           6240000  ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำ...
# 4           2685000  ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุ...
# ..              ...                                                ...
# 687         3686000                                 ขุดลอกคลองผักกะเฉด
# 688         2575000                            ขุดลอกคลองบึงทรายกองดิน
# 689          689000                                  ขุดลอกลำรางซาฟารี
# 690          464000                                ขุดลอกลำรางตาจันทร์
# 691         7578000          ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล
#
#                Department
# 0        สำนักการระบายน้ำ
# 1        สำนักการระบายน้ำ
# 2        สำนักการระบายน้ำ
# 3        สำนักการระบายน้ำ
# 4        สำนักการระบายน้ำ
# ..                    ...
# 687  สำนักงานเขตคลองสามวา
# 688  สำนักงานเขตคลองสามวา
# 689  สำนักงานเขตคลองสามวา
# 690  สำนักงานเขตคลองสามวา
# 691     สำนักงานเขตบางบอน
#
# [692 rows x 3 columns]

# %%
data1[['Approved_buget','Item_name', 'Department']][6:11]
# Out:
#     Approved_buget                                          Item_name  \
# 6           225400  ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระย...
# 7           452500  ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวาง...
# 8           447000  ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเ...
# 9           497000  ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำม...
# 10          189500                ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50
#
#               Department
# 6     สำนักงานเขตมีนบุรี
# 7     สำนักงานเขตมีนบุรี
# 8     สำนักงานเขตหนองจอก
# 9     สำนักงานเขตหนองจอก
# 10  สำนักงานเขตภาษีเจริญ

# %% [markdown]
# ## มุมมองแบบ Array

# %%
 data1.iloc[0, 0] # .iloc เปลี่ยนมุมมองเป็น np.arry  ชี้เป็นเเถว คอลัม ติดลบ สไลด์ได้
# Out:
# 'งบประจำปี'

# %%
 data1.iloc[-6,5]
# Out:
# nan

# %%
data1.tail(7)
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 685     งบเพิ่มเติม         1           66         50460000
# 686     งบเพิ่มเติม         1           66         50460000
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Core_budget_code Expenditure_category  \
# 685  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 686  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 691     สำนักงานเขตบางบอน              NaN              งบลงทุน
#
#                                      Item_name  Approved_buget
# 685                           ขุดลอกคลองกีบหมู         2925000
# 686                         ขุดลอกคลองลำกะโหลก         3875000
# 687                         ขุดลอกคลองผักกะเฉด         3686000
# 688                    ขุดลอกคลองบึงทรายกองดิน         2575000
# 689                          ขุดลอกลำรางซาฟารี          689000
# 690                        ขุดลอกลำรางตาจันทร์          464000
# 691  ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล         7578000

# %% [markdown]
# # Table Slicing
# ไม่ค่อยมีประสิทธิภาพ
# ต้องทราบพิกัด

# %%
data1.iloc[-20 :,7:10]
# Out:
#                                              Item_name  Approved_buget
# 672  ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประ...          472000
# 673  ขุดลอกลำกระโดงแยกคลองบางขี้แก้ง (หมู่บ้านเอเวอ...          492000
# 674                         ขุดลอกคลองแยกคลองตาเทียม 1          469000
# 675  ขุดลอกลำกระโดงระหว่างซอยเพชรเกษม 43 กับ ซอยเพช...          493000
# 676                          ขุดลอกคลองแยกคลองยายเพิ่ม          481000
# 677                    ขุดลอกลำกระโดงข้างหมู่บ้านวรนุช          492000
# 678                                    ขุดลอกคลองตาตี่          483000
# 679                        ขุดลอกลำกระโดงข้างเดอะมอลล์          462000
# 680                      ขุดลอกลำกระโดงข้างบ้านบางแค 2          499000
# 681                                   ขุดลอกลำรางตาเชย         3559000
# 682                              ขุดลอกลำรางไทยเอราวัณ         3494000
# 683                             ขุดลอกคลองหนึ่งตะวันตก         4330000
# 684                               ขุดลอกคลองสองตะวันตก         9832000
# 685                                   ขุดลอกคลองกีบหมู         2925000
# 686                                 ขุดลอกคลองลำกะโหลก         3875000
# 687                                 ขุดลอกคลองผักกะเฉด         3686000
# 688                            ขุดลอกคลองบึงทรายกองดิน         2575000
# 689                                  ขุดลอกลำรางซาฟารี          689000
# 690                                ขุดลอกลำรางตาจันทร์          464000
# 691          ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล         7578000

# %% [markdown]
#  ## table Query

# %% [markdown]
# #### อยากได้รายการที่ได้รับอนุมัติงบเกิน 1 ล้านบาท
# ```df[logics]``` โดยที่ logics จะต้องมีจำนวนสมาชิกเท่ากับจำนวนแถวของ df

# %%
small_df = data1.iloc[-5:,:]
small_df
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Core_budget_code Expenditure_category  \
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 691     สำนักงานเขตบางบอน              NaN              งบลงทุน
#
#                                      Item_name  Approved_buget
# 687                         ขุดลอกคลองผักกะเฉด         3686000
# 688                    ขุดลอกคลองบึงทรายกองดิน         2575000
# 689                          ขุดลอกลำรางซาฟารี          689000
# 690                        ขุดลอกลำรางตาจันทร์          464000
# 691  ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล         7578000

# %%
small_df[[False, True, True, False, False]]
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
#
#                Department Core_budget_code Expenditure_category  \
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
#
#                    Item_name  Approved_buget
# 688  ขุดลอกคลองบึงทรายกองดิน         2575000
# 689        ขุดลอกลำรางซาฟารี          689000

# %% [markdown]
# ## ปั้น List of Logics จากตาราง Pandas

# %%
small_df['Approved_buget']< 1000000
# Out:
# 687    False
# 688    False
# 689     True
# 690     True
# 691    False
# Name: Approved_buget, dtype: bool

# %%
small_df[small_df['Approved_buget']< 1000000]
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
#
#                Department Core_budget_code Expenditure_category  \
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
#
#                Item_name  Approved_buget
# 689    ขุดลอกลำรางซาฟารี          689000
# 690  ขุดลอกลำรางตาจันทร์          464000

# %% [markdown]
# #### Quiz3 อยากได้รายการที่ได้รับอนุมัติงบมากกว่า 1 ล้านบาท แต่ไม่เกิน 2 ล้านบาท

# %%
data1[(data1['Approved_buget']> 1000000) & (data1['Approved_buget'] <= 2000000)]
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 0         งบประจำปี         0           62         11000000
# 1         งบประจำปี         0           62         11000000
# 5         งบประจำปี         0           62         11000000
# 22        งบประจำปี         0           63         11000000
# 25        งบประจำปี         0           63         11000000
# ..              ...       ...          ...              ...
# 660     งบเพิ่มเติม         1           66         50350000
# 662     งบเพิ่มเติม         1           66         50350000
# 665     งบเพิ่มเติม         1           66         50350000
# 666     งบเพิ่มเติม         1           66         50360000
# 670     งบเพิ่มเติม         1           66         50360000
#
#              Department                                   Core_budget_code  \
# 0      สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 1      สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 5      สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 22     สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 25     สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# ..                  ...                                                ...
# 660  สำนักงานเขตบางพลัด                                                NaN
# 662  สำนักงานเขตบางพลัด                                                NaN
# 665  สำนักงานเขตบางพลัด                                                NaN
# 666   สำนักงานเขตจอมทอง                                                NaN
# 670   สำนักงานเขตจอมทอง                                                NaN
#
#     Expenditure_category                                          Item_name  \
# 0                งบลงทุน        ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ
# 1                งบลงทุน  ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคช...
# 5                งบลงทุน  ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองม...
# 22               งบลงทุน      ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง
# 25               งบลงทุน  ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธ...
# ..                   ...                                                ...
# 660              งบลงทุน                                 ขุดลอกคลองสะพานยาว
# 662              งบลงทุน         ขุดลอกคลองบางรักและคูน้ำซอยจรัญสนิทวงศ์ 89
# 665              งบลงทุน                           ขุดลอกคลองวัดน้อยนางหงษ์
# 666              งบลงทุน  ขุดลอกคลองลัดบางสะแก (1),(2) จากคลองบางค้อและค...
# 670              งบลงทุน  ขุดลอกลำกระโดงสาธารณประโยชน์แยกคลองต้นไทร (3),...
#
#      Approved_buget
# 0           1193000
# 1           1100000
# 5           1207000
# 22          1508000
# 25          1975000
# ..              ...
# 660         1756000
# 662         1859000
# 665         1187000
# 666         1581000
# 670         1388000
#
# [132 rows x 9 columns]

# %%
small_df[(small_df['Approved_buget']> 1000000) & (small_df['Approved_buget'] <= 2000000)]
# Out:
# Empty DataFrame
# Columns: [Budget_resource, Issue_No, Fiscal_year, Department_code, Department, Core_budget_code, Expenditure_category, Item_name, Approved_buget]
# Index: []

# %%
data1[data1['propertytype_name_en']== 'condo'] #ใช้ logi
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'propertytype_name_en'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-df8c806a1bcb> in <cell line: 1>()
# ----> 1 data1[data1['propertytype_name_en']== 'condo'] #ใช้ logi
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'propertytype_name_en'

# %%
data1['propertytype_name_en']== 'condo'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'propertytype_name_en'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-c1840078db50> in <cell line: 1>()
# ----> 1 data1['propertytype_name_en']== 'condo'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'propertytype_name_en'

# %%
data1[data1['price_min'] > 10000000]
# Out:
#        row_number               unittype_id                project_id  \
# 5           30766             unittype_8026              project_2694
# 11           2452             unittype_8521              project_2906
# 31          17879  5f682d5d0499a4001b30c305  5f6472855bdc5300198eb80a
# 35           6309             unittype_3461               project_754
# 37          26913            unittype_23137              project_9231
# ...           ...                       ...                       ...
# 42576       35213            unittype_22962              project_8609
# 42606       24384            unittype_14126              project_5602
# 42607       13546            unittype_40152             project_17505
# 42618       22299            unittype_13674              project_5356
# 42619       11944            unittype_34884             project_15005
#
#                    name_th  propertytype_id propertytype_name_en  \
# 5            Luciano Grand                1       Detached House
# 11      New Villa Valdivia                1       Detached House
# 31              2BR Duplex                2                Condo
# 35                  Type C                1       Detached House
# 37               4 Bedroom                2                Condo
# ...                    ...              ...                  ...
# 42576            Manhattan                1       Detached House
# 42606      ทาวน์โฮมสามชั้น                3             Townhome
# 42607            2 Bedroom                2                Condo
# 42618  บ้านเดี่ยวชั้นเดียว                1       Detached House
# 42619             Ametrine                1       Detached House
#
#       propertytype_name_th  area_total_min_wa  area_usable_min   price_min  \
# 5                     บ้าน               70.5            198.0  11700000.0
# 11                    บ้าน                NaN            441.0  36900000.0
# 31                   คอนโด                NaN            293.0  34222500.0
# 35                    บ้าน                NaN            390.0  11000000.0
# 37                   คอนโด                NaN            305.0  24000000.0
# ...                    ...                ...              ...         ...
# 42576                 บ้าน                NaN            465.0  28900000.0
# 42606             ทาวน์โฮม                NaN            349.0  18000000.0
# 42607                คอนโด                NaN             71.0  17000000.0
# 42618                 บ้าน                NaN            130.0  36500000.0
# 42619                 บ้าน                NaN            353.0  23590000.0
#
#        ...  count_room_guest  count_room_kitchen  count_room_living  \
# 5      ...               NaN                 NaN                NaN
# 11     ...               1.0                 1.0                1.0
# 31     ...               NaN                 1.0                1.0
# 35     ...               NaN                 1.0                1.0
# 37     ...               NaN                 NaN                NaN
# ...    ...               ...                 ...                ...
# 42576  ...               NaN                 2.0                2.0
# 42606  ...               1.0                 2.0                NaN
# 42607  ...               NaN                 1.0                1.0
# 42618  ...               NaN                 NaN                1.0
# 42619  ...               1.0                 1.0                1.0
#
#        count_room_maid  count_room_storage  count_room_utility  \
# 5                  NaN                 NaN                 NaN
# 11                 1.0                 NaN                 NaN
# 31                 NaN                 NaN                 NaN
# 35                 NaN                 NaN                 NaN
# 37                 NaN                 NaN                 NaN
# ...                ...                 ...                 ...
# 42576              1.0                 NaN                 NaN
# 42606              NaN                 NaN                 NaN
# 42607              NaN                 NaN                 NaN
# 42618              NaN                 NaN                 NaN
# 42619              1.0                 1.0                 NaN
#
#               date_created         date_updated  source  \
# 5      2021-11-12 13:22:43  2020-10-14 19:35:20  baania
# 11     2021-11-12 13:22:43  2020-10-14 19:35:47  baania
# 31     2021-11-12 13:26:37  2020-12-25 11:27:21  baania
# 35     2020-12-04 10:44:19  2020-10-14 21:21:23  baania
# 37     2021-11-12 13:21:59  2020-10-14 01:08:28  baania
# ...                    ...                  ...     ...
# 42576  2021-11-12 13:33:58  2021-10-03 15:21:58  baania
# 42606  2020-12-04 10:45:58  2020-10-14 22:59:34  baania
# 42607  2021-11-12 13:23:03  2020-10-14 20:30:43  baania
# 42618  2020-12-04 10:38:03  2020-10-14 00:47:50  baania
# 42619  2022-06-03 01:00:11  2022-06-03 00:51:19  baania
#
#                                             url_unittype
# 5      https://baania.com/th/project/คาซ่า-แกรนด์-ตาก...
# 11     https://baania.com/th/project/แกรนด์-บางกอก-บู...
# 31     https://baania.com/th/project/ไบรท์-ภูเก็ต-5f6...
# 35     https://baania.com/th/project/บ้านล้านนาธารา-เ...
# 37     https://baania.com/th/project/บางกอก-การ์เด้น-...
# ...                                                  ...
# 42576  https://baania.com/th/project/เดอะ-เจนทริ-สุขุ...
# 42606  https://baania.com/th/project/เดอะ-ซีนีธ-5602/...
# 42607  https://baania.com/th/project/เดอะ-ไลน์-สาทร-1...
# 42618  https://baania.com/th/project/บ้านศุธาวัลย์-53...
# 42619  https://baania.com/th/project/เศรษฐสิริ-แจ้งวั...
#
# [3481 rows x 27 columns]

# %%
data1[data1['price_min'] > 10000000].describe()
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count   3481.000000      3481.000000         304.000000      3354.000000
# mean   21066.205401       215.859523          52.622796       286.948606
# std    12478.117102      2035.944151          31.406177       185.081647
# min        1.000000         1.000000           1.000000        30.000000
# 25%     9796.000000         1.000000          30.000000       155.000000
# 50%    21525.000000         1.000000          51.400000       265.000000
# 75%    32420.000000         2.000000          72.625000       362.750000
# max    42620.000000     20000.000000         335.000000      2548.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  3.481000e+03            138.000000             0.0
# mean   2.577675e+07              4.536232             NaN
# std    2.789259e+07              2.015123             NaN
# min    1.003000e+07              1.000000             NaN
# 25%    1.300000e+07              3.000000             NaN
# 50%    1.700000e+07              4.000000             NaN
# 75%    2.790200e+07              5.750000             NaN
# max    5.800000e+08             10.000000             NaN
#
#        count_floor_internal  count_parking  count_room_bath  count_room_bed  \
# count           2149.000000    1784.000000      3420.000000     3411.000000
# mean               2.346208       2.867152         3.687427        3.357666
# std                0.816617       1.284865         1.458689        1.101538
# min                0.000000       1.000000         0.000000        0.000000
# 25%                2.000000       2.000000         3.000000        3.000000
# 50%                2.000000       3.000000         4.000000        3.000000
# 75%                3.000000       3.000000         5.000000        4.000000
# max                7.000000      10.000000        10.000000       10.000000
#
#        count_room_dinning  count_room_guest  count_room_kitchen  \
# count         1570.000000       1236.000000         1897.000000
# mean             1.007006          1.046926            1.061676
# std              0.083437          0.222751            0.247118
# min              1.000000          1.000000            1.000000
# 25%              1.000000          1.000000            1.000000
# 50%              1.000000          1.000000            1.000000
# 75%              1.000000          1.000000            1.000000
# max              2.000000          3.000000            3.000000
#
#        count_room_living  count_room_maid  count_room_storage  \
# count        1396.000000       989.000000          497.000000
# mean            1.169054         1.070779            1.108652
# std             0.473001         0.275603            0.411853
# min             1.000000         1.000000            1.000000
# 25%             1.000000         1.000000            1.000000
# 50%             1.000000         1.000000            1.000000
# 75%             1.000000         1.000000            1.000000
# max             5.000000         4.000000            4.000000
#
#        count_room_utility
# count           83.000000
# mean             1.120482
# std              0.424769
# min              1.000000
# 25%              1.000000
# 50%              1.000000
# 75%              1.000000
# max              4.000000

# %% [markdown]
# # Quiz 4
# 1. ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ร้านบาท
# 2. พื้นที่ และ จำนวนห้องนอนของบ้านที่แพงที่สุด
# 3. จำนวนที่จอดรถและห้องน้ำของบ้านที่ถูกที่สุด
# 4. ชนิดของบ้านที่แพงที่สุด
# 5. บ้านชนิดไหนมีปริมาณมากที่สุด

# %%
# 1. ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ร้านบาท
data1[(data1['price_min'] >=3000000) & (data1['price_min']<=5000000)].describe()
# Ans 3.928111e+06	 = 3.928111  ล้านบาท
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count   8943.000000      8943.000000        1066.000000      8148.000000
# mean   21153.925976      1285.383987          46.709559       138.785306
# std    12338.077057      4901.447720          18.555223        66.760066
# min        2.000000         1.000000           2.000000        20.100000
# 25%    10042.500000         1.000000          30.000000        96.000000
# 50%    21864.000000         2.000000          50.000000       145.000000
# 75%    32198.000000         3.000000          60.000000       178.000000
# max    42617.000000     20000.000000          99.000000       896.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  8.943000e+03            418.000000             0.0
# mean   3.922594e+06              2.653110             NaN
# std    5.847665e+05              1.128124             NaN
# min    3.000000e+06              1.000000             NaN
# 25%    3.450000e+06              2.000000             NaN
# 50%    3.880000e+06              3.000000             NaN
# 75%    4.400000e+06              3.000000             NaN
# max    5.000000e+06              7.000000             NaN
#
#        count_floor_internal  count_parking  count_room_bath  count_room_bed  \
# count           6917.000000    5602.000000      8749.000000     8604.000000
# mean               2.132716       1.877722         2.406904        2.736634
# std                0.577204       0.497313         0.915960        0.986672
# min                0.000000       1.000000         0.000000        0.000000
# 25%                2.000000       2.000000         2.000000        2.000000
# 50%                2.000000       2.000000         3.000000        3.000000
# 75%                2.000000       2.000000         3.000000        3.000000
# max                4.000000      10.000000         9.000000       10.000000
#
#        count_room_dinning  count_room_guest  count_room_kitchen  \
# count          3290.00000       3239.000000         4791.000000
# mean              1.00152          1.005557            1.016489
# std               0.03896          0.074351            0.127361
# min               1.00000          1.000000            1.000000
# 25%               1.00000          1.000000            1.000000
# 50%               1.00000          1.000000            1.000000
# 75%               1.00000          1.000000            1.000000
# max               2.00000          2.000000            2.000000
#
#        count_room_living  count_room_maid  count_room_storage  \
# count        1963.000000       150.000000         1223.000000
# mean            1.028018         1.033333            1.038430
# std             0.171131         0.214153            0.200641
# min             1.000000         1.000000            1.000000
# 25%             1.000000         1.000000            1.000000
# 50%             1.000000         1.000000            1.000000
# 75%             1.000000         1.000000            1.000000
# max             3.000000         3.000000            3.000000
#
#        count_room_utility
# count          161.000000
# mean             1.105590
# std              0.396902
# min              1.000000
# 25%              1.000000
# 50%              1.000000
# 75%              1.000000
# max              3.000000

# %%
price_mean = data1[(data1['price_min'] >=3000000) & (data1['price_min']<=5000000)]['price_min'].mean()

# %%
print(f'ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ล้านบาท คือ {int(price_mean):,}')
# Out:
# ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ล้านบาท คือ 3,922,594

# %%
#2.พื้นที่และจำนวนห้องนอนของบ้านที่แพงที่สุด
data1['price_min'].max()
# Out:
# 580000000.0

# %%
data1[data1['price_min']==580000000][['area_usable_min','count_room_bed']]
# Out:
#        area_usable_min  count_room_bed
# 33122           1182.0             3.0

# %%
data1[data1['price_min']==data1['price_min'].max()][['area_usable_min','count_room_bed','price_min']]
# Out:
#        area_usable_min  count_room_bed    price_min
# 33122           1182.0             3.0  580000000.0

# %%
data1[data1['price_min']==data1['price_min'].max()]

# %%
#3.จำนวนที่จอดรถและห้องน้ำที่ถูกที่สุด
data1['price_min'].min()
# Out:
# 100000.0

# %%
data1[data1['price_min']==100000][['count_parking','count_room_bath']]
# Out:
#        count_parking  count_room_bath
# 8640             NaN              1.0
# 11019            NaN              1.0
# 17941            NaN              1.0
# 30364            NaN              1.0

# %%
data1[data1['price_min']==data1['price_min'].min()][['propertytype_name_en','count_parking','count_room_bath','price_min']]
# Out:
#       propertytype_name_en  count_parking  count_room_bath  price_min
# 8640                 Condo            NaN              1.0   100000.0
# 11019                Condo            NaN              1.0   100000.0
# 17941                Condo            NaN              1.0   100000.0
# 30364                Condo            NaN              1.0   100000.0

# %%
# 4. ชนิดของบ้านที่แพงที่สุด
data1.describe()
data1[data1['price_min'] == 580000000]
# Ans Condo
# Out:
#        row_number     unittype_id     project_id    name_th  propertytype_id  \
# 33122        8629  unittype_37324  project_16305  Penthouse                2
#
#       propertytype_name_en propertytype_name_th  area_total_min_wa  \
# 33122                Condo                คอนโด                NaN
#
#        area_usable_min    price_min  ...  count_room_guest  \
# 33122           1182.0  580000000.0  ...               NaN
#
#        count_room_kitchen  count_room_living  count_room_maid  \
# 33122                 NaN                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 33122                 NaN                 NaN  2021-11-12 13:20:31
#
#               date_updated  source  \
# 33122  2020-10-14 00:55:50  baania
#
#                                             url_unittype
# 33122  https://baania.com/th/project/เดอะ-สุโขทัย-เรส...
#
# [1 rows x 27 columns]

# %%
# 4. ชนิดของบ้านที่แพงที่สุด
data1['propertytype_name_en'][data1['price_min'] == 580000000]
# Out:
# 33122    Condo
# Name: propertytype_name_en, dtype: object

# %%
data1[data1['price_min']==data1['price_min'].max()][['propertytype_name_en','price_min']]
# Out:
#       propertytype_name_en    price_min
# 33122                Condo  580000000.0

# %%
#5. บ้านชนิดไหนมีปริมาณมากที่สุด
data1['propertytype_name_en'].describe()
# Out:
# count              42625
# unique                11
# top       Detached House
# freq               17670
# Name: propertytype_name_en, dtype: object

# %%
import os

# %%
path = '/content/drive/My Drive/dataviz_2021_data'

# %%
covid_file_path = os.path.join(path,'pm-20-jan-2021.csv')
print(covid_file_path)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-20-jan-2021.csv

# %%
a = path + '/pm-18-jan-2021.csv'
print(a)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-18-jan-2021.csv

# %% [markdown]
# ## load data to memory

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]

# %%
data_covid.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %% [markdown]
# NaN = Not a Number

# %%
data_covid.head(20)
# Out:
#     No.  ...                                               risk
# 0     1  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 1     2  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2     3  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 3     4  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 4     5  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 5     6  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 6     7  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 7     8  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 8     9  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 9    10  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 10   11  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11   12  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12   13  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 13   14  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 14   15  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 15   16  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 16   17  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 17   18  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 18   19  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 19   20  ...                      คนไทยเดินทางกลับจากต่างประเทศ
#
# [20 rows x 10 columns]

# %%
data_covid.tail()
# Out:
#          No.  ...                                         risk
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5 rows x 10 columns]

# %%
data_covid.shape
# Out:
# (12653, 10)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
data_covid['province_of_onset']
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 12648           ชลบุรี
# 12649            ระยอง
# 12650            ระยอง
# 12651            ระยอง
# 12652              ตาก
# Name: province_of_onset, Length: 12653, dtype: object

# %%
data_covid['risk'][12649]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %% [markdown]
# #### .iloc

# %%
data_covid.iloc[4,7]
# Out:
# 'กรุงเทพมหานคร'

# %% [markdown]
# # เรียนถึงนี่ 12 Jan 2022

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = data_covid[['province_of_onset','announce_date','risk']]
smaller_table
# Out:
#       province_of_onset  ...                                         risk
# 0         กรุงเทพมหานคร  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         กรุงเทพมหานคร  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                นครปฐม  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         กรุงเทพมหานคร  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         กรุงเทพมหานคร  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                 ...  ...                                          ...
# 12648            ชลบุรี  ...                             State Quarantine
# 12649             ระยอง  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650             ระยอง  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651             ระยอง  ...                                Cluster ระยอง
# 12652               ตาก  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 3 columns]

# %% [markdown]
# #### ตัดเฉพาะ rows ที่ต้องการ

# %% [markdown]
# ##### แบบง่าย แต่ใช้การอะไรไม่ค่อยจะได้ (มองเป็น array แล้วตัดแบบ array)

# %%
data_covid.iloc[1:5,:]
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %% [markdown]
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# ```pddf```[list_of_logical_values] คือการเลือก row ที่ logical values เป็น True

# %%
data_covid['province_of_onset']
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 12648           ชลบุรี
# 12649            ระยอง
# 12650            ระยอง
# 12651            ระยอง
# 12652              ตาก
# Name: province_of_onset, Length: 12653, dtype: object

# %%
data_covid['province_of_onset']=='ขอนแก่น'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12648    False
# 12649    False
# 12650    False
# 12651    False
# 12652    False
# Name: province_of_onset, Length: 12653, dtype: bool

# %%
data_covid[data_covid['province_of_onset']=='ขอนแก่น']
# Out:
#          No.  ...                                           risk
# 180      181  ...                                        สนามมวย
# 462      463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2673    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5948    5949  ...                              Cluster สมุทรสาคร
# 6082    6083  ...                              Cluster สมุทรสาคร
# 9333    9334  ...                           อยู่ระหว่างการสอบสวน
# 9334    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                           อยู่ระหว่างการสอบสวน
# 11697  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11698  11699  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [14 rows x 10 columns]

# %%
data_covid[data_covid['age']>=70]
# Out:
#          No.  ...                                               risk
# 1          2  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 7          8  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 24        25  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 82        83  ...                                            สนามมวย
# ...      ...  ...                                                ...
# 11694  11695  ...      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 11700  11701  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11730  11731  ...                                  Cluster สมุทรสาคร
# 11741  11742  ...                               อยู่ระหว่างการสอบสวน
# 12102  12103  ...                                  Cluster สมุทรสาคร
#
# [245 rows x 10 columns]

# %% [markdown]
# การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
eight_rows_covid = data_covid.iloc[:8,3:] # ตารางตัวอย่าง
eight_rows_covid
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  หญิง  74.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  หญิง  73.0  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  หญิง  66.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6  หญิง  57.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 7  หญิง  73.0  ...            หัวหิน  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [8 rows x 7 columns]

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]   #2.   ใส่ list ที่ มีค่า logic ของ แต่ละ row โดยที่ ค่า True คือ เลือก ค่า False คือไม่เลืิอก
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  หญิง  73.0  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 7 columns]

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'  #สร้าง list ของ logical expression
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: province_of_onset, dtype: bool

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']  #เราเอา 2 บรรทัดบนมาบวกกัน
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  หญิง  74.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  หญิง  66.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6  หญิง  57.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [6 rows x 7 columns]

# %%
eight_rows_covid['district_of_onset'] == 'เมือง'
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: district_of_onset, dtype: bool

# %%
import numpy as np

# %% [markdown]
# $.isnull()$ ใช้ตรวจสอบว่าเป็น NaN หรือไม่

# %%
eight_rows_covid['district_of_onset'].isnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: district_of_onset, dtype: bool

# %%
sum(eight_rows_covid['district_of_onset'].isnull())
# Out:
# 6

# %% [markdown]
# Quiz (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1.   คำนวณ อายุเฉลี่ย ของ**ผู้ชาย** ในข้อมูลทั้งหมด
# 2.   คำนวณ อายุเฉลี่ย ของ**ผู้ชาย** ในจังหวัดขอนแก่น
# 3.   หาจำนวนผู้ป่วยที่เป็นคน **ที่ไม่ใช่คนไทย**

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
female = this_data[this_data['sex']=='หญิง']
female
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 4      หญิง  66.0     กรุงเทพมหานคร
# 5      หญิง  33.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [5332 rows x 3 columns]

# %%
female['age']
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 4        66.0
# 5        33.0
#          ...
# 12648    44.0
# 12649    52.0
# 12650    23.0
# 12651    29.0
# 12652    22.0
# Name: age, Length: 5332, dtype: float64

# %%
sum = 0
N = 0
for a in female['age']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง 36.63955450022614

# %%
female_KK = female[female['province_of_onset']=='ขอนแก่น']

sum = 0
N = 0
for a in female_KK['age']:

    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น 41.57142857142857

# %%
female[(female['province_of_onset']=='ขอนแก่น') | (female['province_of_onset']=='หนองคาย')]
# Out:
#         sex   age province_of_onset
# 462    หญิง  36.0           ขอนแก่น
# 1051   หญิง  30.0           หนองคาย
# 1970   หญิง  70.0           ขอนแก่น
# 2637   หญิง  63.0           ขอนแก่น
# 5948   หญิง  32.0           ขอนแก่น
# 6082   หญิง  36.0           ขอนแก่น
# 10834  หญิง  40.0           หนองคาย
# 11697  หญิง  17.0           ขอนแก่น
# 11698  หญิง  37.0           ขอนแก่น

# %% [markdown]
# #### หาจำนวนคนป่วยที่ไม่ใช่คนไทย

# %%
import numpy as np

# %%
np.sum(data_covid['nationality'].dropna() != 'Thailand')
# Out:
# 4129

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
this_data.shape #(12423, 3)
# Out:
# (12653, 3)

# %%
this_data.dropna()
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8478 rows x 3 columns]

# %%
print(data_covid.shape)
print(data_covid.dropna().shape)
# Out:
# (12653, 10)
# (6655, 10)

# %%
this_data.dropna(subset=['age','sex'])
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8880 rows x 3 columns]

# %%
print(this_data.dropna().shape)
print(this_data.dropna(subset=['sex','age']).shape)
# Out:
# (8478, 3)
# (8880, 3)

# %% [markdown]
# # ตรวจสอบ Missing (```isnull()```)

# %%
data1.isnull()
# Out:
#      Budget_resource  Issue_No  Fiscal_year  Department_code  Department  \
# 0              False     False        False            False       False
# 1              False     False        False            False       False
# 2              False     False        False            False       False
# 3              False     False        False            False       False
# 4              False     False        False            False       False
# ..               ...       ...          ...              ...         ...
# 687            False     False        False            False       False
# 688            False     False        False            False       False
# 689            False     False        False            False       False
# 690            False     False        False            False       False
# 691            False     False        False            False       False
#
#      Core_budget_code  Expenditure_category  Item_name  Approved_buget
# 0               False                 False      False           False
# 1               False                 False      False           False
# 2               False                 False      False           False
# 3               False                 False      False           False
# 4               False                 False      False           False
# ..                ...                   ...        ...             ...
# 687              True                 False      False           False
# 688              True                 False      False           False
# 689              True                 False      False           False
# 690              True                 False      False           False
# 691              True                 False      False           False
#
# [692 rows x 9 columns]

# %%
data1.isnull().any() # .any() เอาค่าความจริงใน column มา OR กัน (ใช้ในการหาค่าว่าง)
# Out:
# Budget_resource         False
# Issue_No                False
# Fiscal_year             False
# Department_code         False
# Department              False
# Core_budget_code         True
# Expenditure_category    False
# Item_name               False
# Approved_buget          False
# dtype: bool

# %%
data1.isnull().all() # .all() เอาค่าความจริงใน column มา AND กัน
# Out:
# Budget_resource         False
# Issue_No                False
# Fiscal_year             False
# Department_code         False
# Department              False
# Core_budget_code        False
# Expenditure_category    False
# Item_name               False
# Approved_buget          False
# dtype: bool

# %%
data1.isnull().any().any() #.any ตัวแรกสรุกคอลัมน์ของแต่ละคอลัมน์มาออลกัน
# Out:
# True

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing (dropna)
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown (fillna)
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.) (fillna)

# %% [markdown]
# ไม่ควรจะลบ  data ออกไปเกิน 5 %

# %% [markdown]
# ## NaN Not a Number
# ## Null Null
# ## NA Not Available/Not Authorised
# ## None

# %% [markdown]
# ## Dropna

# %%
data1.shape
# Out:
# (692, 9)

# %% [markdown]
# Pandas Dropna -> https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html

# %%
data1.dropna().shape
# Out:
# (266, 9)

# %%
data1.dropna(subset=['Fiscal_year']).shape ## ถ้ามี Missing เติม dropna
# Out:
# (692, 9)

# %%
data1.isnull(). any()
# Out:
# Budget_resource         False
# Issue_No                False
# Fiscal_year             False
# Department_code         False
# Department              False
# Core_budget_code         True
# Expenditure_category    False
# Item_name               False
# Approved_buget          False
# dtype: bool

# %%
data1_1 = data1.dropna(subset=['Fiscal_year']).shape

# %%
data1_1.isnull(),any()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-16393e76fee5> in <cell line: 1>()
# ----> 1 data1_1.isnull(),any()
#
# AttributeError: 'tuple' object has no attribute 'isnull'

# %%
data1.dropna(subset=['Fiscal_year'],inplace=True)

# %%
data1.isnull().any()
# Out:
# Budget_resource         False
# Issue_No                False
# Fiscal_year             False
# Department_code         False
# Department              False
# Core_budget_code         True
# Expenditure_category    False
# Item_name               False
# Approved_buget          False
# dtype: bool

# %% [markdown]
# ## FILLNA

# %%
data1.fillna('-',inplace=True)

# %%
set(data1['Core_budget_code'])
# Out:
# {'-',
#  '12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วม',
#  '17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานคร',
#  '28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต'}

# %%
data1.isnull().any()
# Out:
# Budget_resource         False
# Issue_No                False
# Fiscal_year             False
# Department_code         False
# Department              False
# Core_budget_code        False
# Expenditure_category    False
# Item_name               False
# Approved_buget          False
# dtype: bool

# %%
data1
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 0         งบประจำปี         0           62         11000000
# 1         งบประจำปี         0           62         11000000
# 2         งบประจำปี         0           62         11000000
# 3         งบประจำปี         0           62         11000000
# 4         งบประจำปี         0           62         11000000
# ..              ...       ...          ...              ...
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department                                   Core_budget_code  \
# 0        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 1        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 2        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 3        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 4        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# ..                    ...                                                ...
# 687  สำนักงานเขตคลองสามวา                                                  -
# 688  สำนักงานเขตคลองสามวา                                                  -
# 689  สำนักงานเขตคลองสามวา                                                  -
# 690  สำนักงานเขตคลองสามวา                                                  -
# 691     สำนักงานเขตบางบอน                                                  -
#
#     Expenditure_category                                          Item_name  \
# 0                งบลงทุน        ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ
# 1                งบลงทุน  ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคช...
# 2                งบลงทุน          ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข
# 3                งบลงทุน  ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำ...
# 4                งบลงทุน  ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุ...
# ..                   ...                                                ...
# 687              งบลงทุน                                 ขุดลอกคลองผักกะเฉด
# 688              งบลงทุน                            ขุดลอกคลองบึงทรายกองดิน
# 689              งบลงทุน                                  ขุดลอกลำรางซาฟารี
# 690              งบลงทุน                                ขุดลอกลำรางตาจันทร์
# 691              งบลงทุน          ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล
#
#      Approved_buget
# 0           1193000
# 1           1100000
# 2           3075000
# 3           6240000
# 4           2685000
# ..              ...
# 687         3686000
# 688         2575000
# 689          689000
# 690          464000
# 691         7578000
#
# [692 rows x 9 columns]

# %% [markdown]
# ---End---

# %% [markdown]
# ## HW3
#
#
# 1.   รายการที่แพงและถูกที่สุดคือรายการไหน
# 2.   รายการขุดลอกคูคลองของ 'สำนักงานเขตคลองสาน' และ 'สำนักงานเขตคลองสามวา'
# 3.   จากข้อ 2 เขตไหนใช้งบประมาณเยอะกว่ากัน
# 4.   Core Budget ไหน ('12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วม', '17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานคร','28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต') มีค่าเฉลี่ยงบประมาณที่ถูกอนุมัติสูงที่สุด

# %%
data1
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 0         งบประจำปี         0           62         11000000
# 1         งบประจำปี         0           62         11000000
# 2         งบประจำปี         0           62         11000000
# 3         งบประจำปี         0           62         11000000
# 4         งบประจำปี         0           62         11000000
# ..              ...       ...          ...              ...
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department                                   Core_budget_code  \
# 0        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 1        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 2        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 3        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 4        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# ..                    ...                                                ...
# 687  สำนักงานเขตคลองสามวา                                                NaN
# 688  สำนักงานเขตคลองสามวา                                                NaN
# 689  สำนักงานเขตคลองสามวา                                                NaN
# 690  สำนักงานเขตคลองสามวา                                                NaN
# 691     สำนักงานเขตบางบอน                                                NaN
#
#     Expenditure_category                                          Item_name  \
# 0                งบลงทุน        ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ
# 1                งบลงทุน  ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคช...
# 2                งบลงทุน          ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข
# 3                งบลงทุน  ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำ...
# 4                งบลงทุน  ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุ...
# ..                   ...                                                ...
# 687              งบลงทุน                                 ขุดลอกคลองผักกะเฉด
# 688              งบลงทุน                            ขุดลอกคลองบึงทรายกองดิน
# 689              งบลงทุน                                  ขุดลอกลำรางซาฟารี
# 690              งบลงทุน                                ขุดลอกลำรางตาจันทร์
# 691              งบลงทุน          ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล
#
#      Approved_buget
# 0           1193000
# 1           1100000
# 2           3075000
# 3           6240000
# 4           2685000
# ..              ...
# 687         3686000
# 688         2575000
# 689          689000
# 690          464000
# 691         7578000
#
# [692 rows x 9 columns]

# %%
## 1. รายการที่แพงและถูกที่สุดคือรายการไหน
data1['Approved_buget'].describe()
# max 2.850000e+07 = 28.5 ล้านบาท
# min 0.000000e+00 = 0 บาท
# Out:
# count    6.920000e+02
# mean     1.482811e+06
# std      2.464625e+06
# min      0.000000e+00
# 25%      4.100000e+05
# 50%      5.980000e+05
# 75%      1.628250e+06
# max      2.850000e+07
# Name: Approved_buget, dtype: float64

# %%
data1['Approved_buget'].max() # max 2.850000e+07 = 28.5 ล้านบาท
# Out:
# 28500000

# %%
data1[data1['Approved_buget']==28500000][['Item_name','Approved_buget']]
# Out:
#                                              Item_name  Approved_buget
# 576  ขุดลอกคลองพระยาสุเรนทร์ จากคลองหกวาถึงคลองบางช...        28500000

# %%
data1['Approved_buget'].min() # min 0.000000e+00 = 0 บาท
# Out:
# 0

# %%
data1[data1['Approved_buget']==0][['Item_name','Approved_buget']]
# Out:
#                                              Item_name  Approved_buget
# 612  ขุดลอกลำกระโดงอำนวยสุข จากคลองบางกอกใหญ่ถึงสุด...               0
# 613  ขุดลอกคลองแยกวัดประดู่ จากคลองบางกอกใหญ่ถึงคลอ...               0
# 631   ขุดลอกคลองต้นโศกจากคลองราษฎร์บูรณะถึงคลองแจงร้อน               0

# %%
data1_1 = data1[['Item_name','Approved_buget']]

# %%
data1_HW3 = data1_1 [(data1_1['Approved_buget'] == data1_1['Approved_buget'].max()) | (data1_1['Approved_buget'] ==data1_1['Approved_buget'].min())]
data1_HW3
# Out:
#                                              Item_name  Approved_buget
# 576  ขุดลอกคลองพระยาสุเรนทร์ จากคลองหกวาถึงคลองบางช...        28500000
# 612  ขุดลอกลำกระโดงอำนวยสุข จากคลองบางกอกใหญ่ถึงสุด...               0
# 613  ขุดลอกคลองแยกวัดประดู่ จากคลองบางกอกใหญ่ถึงคลอ...               0
# 631   ขุดลอกคลองต้นโศกจากคลองราษฎร์บูรณะถึงคลองแจงร้อน               0

# %%
## 2. รายการขุดลอกคูคลองของ 'สำนักงานเขตคลองสาน' และ 'สำนักงานเขตคลองสามวา'
data1[data1['Department']=='สำนักงานเขตคลองสาน']
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 57        งบประจำปี         0           62         50170000
# 58        งบประจำปี         0           62         50170000
# 59        งบประจำปี         0           62         50170000
# 122       งบประจำปี         0           63         50170000
# 123       งบประจำปี         0           63         50170000
# 212       งบประจำปี         0           64         50170000
# 213       งบประจำปี         0           64         50170000
# 214       งบประจำปี         0           64         50170000
# 215       งบประจำปี         0           64         50170000
# 271       งบประจำปี         0           65         50170000
# 441       งบประจำปี         0           66         50170000
# 442       งบประจำปี         0           66         50170000
# 443       งบประจำปี         0           66         50170000
#
#              Department Core_budget_code Expenditure_category  \
# 57   สำนักงานเขตคลองสาน                -              งบลงทุน
# 58   สำนักงานเขตคลองสาน                -              งบลงทุน
# 59   สำนักงานเขตคลองสาน                -              งบลงทุน
# 122  สำนักงานเขตคลองสาน                -              งบลงทุน
# 123  สำนักงานเขตคลองสาน                -              งบลงทุน
# 212  สำนักงานเขตคลองสาน                -              งบลงทุน
# 213  สำนักงานเขตคลองสาน                -              งบลงทุน
# 214  สำนักงานเขตคลองสาน                -              งบลงทุน
# 215  สำนักงานเขตคลองสาน                -              งบลงทุน
# 271  สำนักงานเขตคลองสาน              NaN              งบลงทุน
# 441  สำนักงานเขตคลองสาน              NaN              งบลงทุน
# 442  สำนักงานเขตคลองสาน              NaN              งบลงทุน
# 443  สำนักงานเขตคลองสาน              NaN              งบลงทุน
#
#                                              Item_name  Approved_buget
# 57                                  ขุดลอกคูน้ำสารภี 1          513000
# 58                             ขุดลอกคลองวัดทองเพลง\n          2218000
# 59   ขุดลอกลำกระโดงชุมชนสองร้อยห้อง\nจากบริเวณบ้านเ...           89000
# 122  ขุดลอกคลองวัดทองธรรมชาติและคลองแยกคลองวัดทองธร...          500000
# 123                                   ขุดลอกคลองโรงปลา           90000
# 212                         ขุดลอกลำกระโดงซอยอิสรภาพ 3          162000
# 213       ขุดลอกคลองหลังวัดพิชัยญาติและคลองวัดน้อยเก่า          209000
# 214                                ขุดลอกคลองพระยาเกษม          487000
# 215                    ขุดลอกคลองข้างโรงเรียนปทุมวิทยา           80000
# 271  ขุดลอกคลองวัดน้อยใหม่จากแยกบ้านแขกถึงคลองสมเด็...          659000
# 441  ขุดลอกคลองโรงหนัง จากคลองบางไส้ไก่ถึงแม่น้ำเจ้...         1325000
# 442  ขุดลอกคลองข้างโรงน้ำแข็ง จากสุดระยะคลองถึงแม่น...          358000
# 443  ขุดลอกคลองข้างวัดอนงค์ จากคลองหลัง\nวัดพิชัยญา...          205000

# %%
data1[data1['Department']=='สำนักงานเขตคลองสามวา']
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 252       งบประจำปี         0           64         50460000
# 253       งบประจำปี         0           64         50460000
# 400     งบเพิ่มเติม         1           65         50460000
# 401     งบเพิ่มเติม         1           65         50460000
# 402     งบเพิ่มเติม         1           65         50460000
# 403     งบเพิ่มเติม         1           65         50460000
# 404     งบเพิ่มเติม         1           65         50460000
# 681     งบเพิ่มเติม         1           66         50460000
# 682     งบเพิ่มเติม         1           66         50460000
# 683     งบเพิ่มเติม         1           66         50460000
# 684     งบเพิ่มเติม         1           66         50460000
# 685     งบเพิ่มเติม         1           66         50460000
# 686     งบเพิ่มเติม         1           66         50460000
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
#
#                Department Core_budget_code Expenditure_category  \
# 252  สำนักงานเขตคลองสามวา                -              งบลงทุน
# 253  สำนักงานเขตคลองสามวา                -              งบลงทุน
# 400  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 401  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 402  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 403  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 404  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 681  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 682  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 683  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 684  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 685  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 686  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
#
#                                              Item_name  Approved_buget
# 252  ขุดลอกคลองสามตะวันตก จากคลองสามวา ถึงคลองพระยา...         6236000
# 253  ขุดลอกคลองสี่ตะวันตก จากคลองสามวา ถึงคลองพระยา...         5815000
# 400  ขุดลอกลำรางวัดแป้นทอง จากคลองสี่ตะวันตก ถึงคลอ...         1246200
# 401  ขุดลอกลำรางครูพัว จากคลองสองตะวันตก ถึงคลองหนึ...          542200
# 402     ขุดลอกลำรางตาชม จากคลองลำควายตาย ถึงคลองบางชัน          452300
# 403  ขุดลอกคลองเจ๊ก จากคลองหนึ่งตะวันตก ถึงสุดเขตคล...         1204500
# 404  ขุดลอกคลองซอยเชื่อมคลองลำแบนกับคลองหนองระแหง จ...          453600
# 681                                   ขุดลอกลำรางตาเชย         3559000
# 682                              ขุดลอกลำรางไทยเอราวัณ         3494000
# 683                             ขุดลอกคลองหนึ่งตะวันตก         4330000
# 684                               ขุดลอกคลองสองตะวันตก         9832000
# 685                                   ขุดลอกคลองกีบหมู         2925000
# 686                                 ขุดลอกคลองลำกะโหลก         3875000
# 687                                 ขุดลอกคลองผักกะเฉด         3686000
# 688                            ขุดลอกคลองบึงทรายกองดิน         2575000
# 689                                  ขุดลอกลำรางซาฟารี          689000
# 690                                ขุดลอกลำรางตาจันทร์          464000

# %%
data1[(data1['Department']=='สำนักงานเขตคลองสาน') | (data1['Department']=='สำนักงานเขตคลองสามวา')]
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 57        งบประจำปี         0           62         50170000
# 58        งบประจำปี         0           62         50170000
# 59        งบประจำปี         0           62         50170000
# 122       งบประจำปี         0           63         50170000
# 123       งบประจำปี         0           63         50170000
# 212       งบประจำปี         0           64         50170000
# 213       งบประจำปี         0           64         50170000
# 214       งบประจำปี         0           64         50170000
# 215       งบประจำปี         0           64         50170000
# 252       งบประจำปี         0           64         50460000
# 253       งบประจำปี         0           64         50460000
# 271       งบประจำปี         0           65         50170000
# 400     งบเพิ่มเติม         1           65         50460000
# 401     งบเพิ่มเติม         1           65         50460000
# 402     งบเพิ่มเติม         1           65         50460000
# 403     งบเพิ่มเติม         1           65         50460000
# 404     งบเพิ่มเติม         1           65         50460000
# 441       งบประจำปี         0           66         50170000
# 442       งบประจำปี         0           66         50170000
# 443       งบประจำปี         0           66         50170000
# 681     งบเพิ่มเติม         1           66         50460000
# 682     งบเพิ่มเติม         1           66         50460000
# 683     งบเพิ่มเติม         1           66         50460000
# 684     งบเพิ่มเติม         1           66         50460000
# 685     งบเพิ่มเติม         1           66         50460000
# 686     งบเพิ่มเติม         1           66         50460000
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
#
#                Department Core_budget_code Expenditure_category  \
# 57     สำนักงานเขตคลองสาน                -              งบลงทุน
# 58     สำนักงานเขตคลองสาน                -              งบลงทุน
# 59     สำนักงานเขตคลองสาน                -              งบลงทุน
# 122    สำนักงานเขตคลองสาน                -              งบลงทุน
# 123    สำนักงานเขตคลองสาน                -              งบลงทุน
# 212    สำนักงานเขตคลองสาน                -              งบลงทุน
# 213    สำนักงานเขตคลองสาน                -              งบลงทุน
# 214    สำนักงานเขตคลองสาน                -              งบลงทุน
# 215    สำนักงานเขตคลองสาน                -              งบลงทุน
# 252  สำนักงานเขตคลองสามวา                -              งบลงทุน
# 253  สำนักงานเขตคลองสามวา                -              งบลงทุน
# 271    สำนักงานเขตคลองสาน              NaN              งบลงทุน
# 400  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 401  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 402  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 403  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 404  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 441    สำนักงานเขตคลองสาน              NaN              งบลงทุน
# 442    สำนักงานเขตคลองสาน              NaN              งบลงทุน
# 443    สำนักงานเขตคลองสาน              NaN              งบลงทุน
# 681  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 682  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 683  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 684  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 685  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 686  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
#
#                                              Item_name  Approved_buget
# 57                                  ขุดลอกคูน้ำสารภี 1          513000
# 58                             ขุดลอกคลองวัดทองเพลง\n          2218000
# 59   ขุดลอกลำกระโดงชุมชนสองร้อยห้อง\nจากบริเวณบ้านเ...           89000
# 122  ขุดลอกคลองวัดทองธรรมชาติและคลองแยกคลองวัดทองธร...          500000
# 123                                   ขุดลอกคลองโรงปลา           90000
# 212                         ขุดลอกลำกระโดงซอยอิสรภาพ 3          162000
# 213       ขุดลอกคลองหลังวัดพิชัยญาติและคลองวัดน้อยเก่า          209000
# 214                                ขุดลอกคลองพระยาเกษม          487000
# 215                    ขุดลอกคลองข้างโรงเรียนปทุมวิทยา           80000
# 252  ขุดลอกคลองสามตะวันตก จากคลองสามวา ถึงคลองพระยา...         6236000
# 253  ขุดลอกคลองสี่ตะวันตก จากคลองสามวา ถึงคลองพระยา...         5815000
# 271  ขุดลอกคลองวัดน้อยใหม่จากแยกบ้านแขกถึงคลองสมเด็...          659000
# 400  ขุดลอกลำรางวัดแป้นทอง จากคลองสี่ตะวันตก ถึงคลอ...         1246200
# 401  ขุดลอกลำรางครูพัว จากคลองสองตะวันตก ถึงคลองหนึ...          542200
# 402     ขุดลอกลำรางตาชม จากคลองลำควายตาย ถึงคลองบางชัน          452300
# 403  ขุดลอกคลองเจ๊ก จากคลองหนึ่งตะวันตก ถึงสุดเขตคล...         1204500
# 404  ขุดลอกคลองซอยเชื่อมคลองลำแบนกับคลองหนองระแหง จ...          453600
# 441  ขุดลอกคลองโรงหนัง จากคลองบางไส้ไก่ถึงแม่น้ำเจ้...         1325000
# 442  ขุดลอกคลองข้างโรงน้ำแข็ง จากสุดระยะคลองถึงแม่น...          358000
# 443  ขุดลอกคลองข้างวัดอนงค์ จากคลองหลัง\nวัดพิชัยญา...          205000
# 681                                   ขุดลอกลำรางตาเชย         3559000
# 682                              ขุดลอกลำรางไทยเอราวัณ         3494000
# 683                             ขุดลอกคลองหนึ่งตะวันตก         4330000
# 684                               ขุดลอกคลองสองตะวันตก         9832000
# 685                                   ขุดลอกคลองกีบหมู         2925000
# 686                                 ขุดลอกคลองลำกะโหลก         3875000
# 687                                 ขุดลอกคลองผักกะเฉด         3686000
# 688                            ขุดลอกคลองบึงทรายกองดิน         2575000
# 689                                  ขุดลอกลำรางซาฟารี          689000
# 690                                ขุดลอกลำรางตาจันทร์          464000

# %%
## 3. จากข้อ 2 เขตไหนใช้งบประมาณเยอะกว่ากัน
# compare = data1[(data1['Department'] == 'สำนักงานเขตคลองสาม') | (data1['Department'] == 'สำนักงานเขตคลองสามวา')]

# %%
data1[data1['Department']=='สำนักงานเขตคลองสาน']['Approved_buget'] .sum()
print(f'สำนักงานเขตคลองสาน ใช้งบประมาณรวม เป็นเงิน',data1[data1['Department']=='สำนักงานเขตคลองสาน']['Approved_buget'] .sum(),f'บาท')
# Out:
# สำนักงานเขตคลองสาน ใช้งบประมาณรวม เป็นเงิน 6895000 บาท

# %%
data1[data1['Department']=='สำนักงานเขตคลองสามวา']['Approved_buget'] .sum()
print(f'สำนักงานเขตคลองสามวา ใช้งบประมาณรวม เป็นเงิน',data1[data1['Department']=='สำนักงานเขตคลองสามวา']['Approved_buget'] .sum(),f'บาท')
# Out:
# สำนักงานเขตคลองสามวา ใช้งบประมาณรวม เป็นเงิน 51378800 บาท

# %%
# Ans เขต สำนักงานเขตคลองสามวา ใช้งบประมาณเยอะกว่า สำนักงานเขตคลองสาน
print(f'เขต สำนักงานเขตคลองสามวา ใช้งบประมาณเยอะกว่า สำนักงานเขตคลองสาน โดยมีงบประมาณอยู่ที่', data1[data1['Department']=='สำนักงานเขตคลองสามวา']['Approved_buget'] .sum(), f'บาท' )
# Out:
# เขต สำนักงานเขตคลองสามวา ใช้งบประมาณเยอะกว่า สำนักงานเขตคลองสาน โดยมีงบประมาณอยู่ที่ 51378800 บาท

# %%
## 4. Core Budget ไหน ('12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วม', '17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานคร',
# '28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต') มีค่าเฉลี่ยงบประมาณที่ถูกอนุมัติสูงที่สุด
set(data1['Core_budget_code'])
# Out:
# {'-',
#  '12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วม',
#  '17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานคร',
#  '28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต',
#  nan}

# %%
core_12 = data1[(data1['Core_budget_code'] == "12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วม")]
core_12
# Out:
#    Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 0        งบประจำปี         0           62         11000000
# 1        งบประจำปี         0           62         11000000
# 2        งบประจำปี         0           62         11000000
# 3        งบประจำปี         0           62         11000000
# 4        งบประจำปี         0           62         11000000
# 5        งบประจำปี         0           62         11000000
# 6        งบประจำปี         0           62         50130000
# 7        งบประจำปี         0           62         50130000
# 10       งบประจำปี         0           62         50210000
# 11       งบประจำปี         0           62         50260000
# 13       งบประจำปี         0           62         50350000
# 15       งบประจำปี         0           62         50400000
# 16       งบประจำปี         0           62         50400000
# 17       งบประจำปี         0           62         50400000
# 18       งบประจำปี         0           62         50400000
# 19       งบประจำปี         0           62         50400000
# 20       งบประจำปี         0           62         50400000
# 21       งบประจำปี         0           62         50400000
# 22       งบประจำปี         0           63         11000000
# 23       งบประจำปี         0           63         11000000
# 24       งบประจำปี         0           63         11000000
# 25       งบประจำปี         0           63         11000000
# 26       งบประจำปี         0           63         11000000
# 29       งบประจำปี         0           63         50220000
# 30       งบประจำปี         0           63         50220000
# 31       งบประจำปี         0           63         50250000
# 32       งบประจำปี         0           63         50250000
#
#               Department                                   Core_budget_code  \
# 0       สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 1       สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 2       สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 3       สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 4       สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 5       สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 6     สำนักงานเขตมีนบุรี  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 7     สำนักงานเขตมีนบุรี  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 10  สำนักงานเขตภาษีเจริญ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 11    สำนักงานเขตจตุจักร  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 13    สำนักงานเขตบางพลัด  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 15      สำนักงานเขตบางแค  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 16      สำนักงานเขตบางแค  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 17      สำนักงานเขตบางแค  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 18      สำนักงานเขตบางแค  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 19      สำนักงานเขตบางแค  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 20      สำนักงานเขตบางแค  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 21      สำนักงานเขตบางแค  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 22      สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 23      สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 24      สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 25      สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 26      สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 29    สำนักงานเขตหนองแขม  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 30    สำนักงานเขตหนองแขม  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 31   สำนักงานเขตดอนเมือง  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 32   สำนักงานเขตดอนเมือง  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
#
#    Expenditure_category                                          Item_name  \
# 0               งบลงทุน        ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ
# 1               งบลงทุน  ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคช...
# 2               งบลงทุน          ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข
# 3               งบลงทุน  ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำ...
# 4               งบลงทุน  ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุ...
# 5               งบลงทุน  ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองม...
# 6               งบลงทุน  ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระย...
# 7               งบลงทุน  ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวาง...
# 10              งบลงทุน                ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50
# 11              งบลงทุน  ขุดลอกคลองทุ่งจากซอยวิภาวดีรังสิต 36 ถึงคลองลา...
# 13              งบลงทุน                           ขุดลอกคลองวัดดาวดึงษาราม
# 15              งบลงทุน             ขุดลอกลำกระโดงข้างโรงเรียนคลองหนองใหญ่
# 16              งบลงทุน                ขุดลอกลำกระโดงข้างบริษัทประยูรวิศว์
# 17              งบลงทุน  ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประ...
# 18              งบลงทุน                      ขุดลอกลำกระโดงข้างบ้านบางแค 2
# 19              งบลงทุน                          ขุดลอกคลองหลวงพ่อบ้านแหลม
# 20              งบลงทุน                            ขุดลอกคลองผู้ใหญ่เส็ง 1
# 21              งบลงทุน               ขุดลอกลำกระโดงข้างห้างเดอะมอลล์บางแค
# 22              งบลงทุน      ขุดลอกคลองนางหงษ์จากคลองแสนแสบถึงถนนบรรทัดทอง
# 23              งบลงทุน  ขุดลอกคลองบางแคจากถนนกาญจนาภิเษกถึงคลองพระยารา...
# 24              งบลงทุน            ขุดลอกคลองบางมดจากคลองสนามชัยถึงคลองสวน
# 25              งบลงทุน  ขุดลอกคลองราษฎร์บูรณะจากแม่น้ำเจ้าพระยาถึงสวนธ...
# 26              งบลงทุน     ขุดลอกคลองแจงร้อนจากแม่น้ำเจ้าพระยาถึงคลองขวาง
# 29              งบลงทุน  ขุดลอกคลองตาปลั่ง 1 จากคลองภาษีเจริญถึงคลองหนา...
# 30              งบลงทุน  ขุดลอกคลองตาปลั่ง 2 จากถนนบางบอน 5 ถึงสุดระยะท...
# 31              งบลงทุน  ขุดลอกลำรางสาธารณะเลียบหมู่บ้านบัณฑิตโฮมตั้งแต...
# 32              งบลงทุน  ขุดลอกลำรางข้างบริษัทไทยเทยิ่น ตั้งแต่ถนนวิภาว...
#
#     Approved_buget
# 0          1193000
# 1          1100000
# 2          3075000
# 3          6240000
# 4          2685000
# 5          1207000
# 6           225400
# 7           452500
# 10          189500
# 11          426000
# 13          258000
# 15          210000
# 16          486000
# 17          454000
# 18          410000
# 19          442000
# 20          347000
# 21          482000
# 22         1508000
# 23         4370000
# 24         6570000
# 25         1975000
# 26         2580000
# 29         4380000
# 30         1626000
# 31         1256000
# 32         1117000

# %%
mean_core12 = core_12['Approved_buget'].mean()
mean_core12
# Out:
# 1676459.2592592593

# %%
core_17 = data1[(data1['Core_budget_code'] == "17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานคร")]
core_17
# Out:
#    Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 27       งบประจำปี         0           63         50150000
# 28       งบประจำปี         0           63         50150000
#
#             Department                                   Core_budget_code  \
# 27  สำนักงานเขตหนองจอก  17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพ...
# 28  สำนักงานเขตหนองจอก  17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพ...
#
#    Expenditure_category                                          Item_name  \
# 27              งบลงทุน  ขุดลอกคลองลำไทรจากคลองลำปลาทิวถึงคลองลำตาจีน แ...
# 28              งบลงทุน  ขุดลอกคลองหกโรงจากคลองหนึ่งถึงคลองสอง แขวงกระท...
#
#     Approved_buget
# 27         1850000
# 28         1825000

# %%
mean_core17 = core_17['Approved_buget'].mean()
mean_core17
# Out:
# 1837500.0

# %%
core_28 = data1[(data1['Core_budget_code'] == "28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต")]
core_28
# Out:
#    Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 8        งบประจำปี         0           62         50150000
# 9        งบประจำปี         0           62         50150000
# 12       งบประจำปี         0           62         50320000
# 14       งบประจำปี         0           62         50370000
#
#             Department                      Core_budget_code  \
# 8   สำนักงานเขตหนองจอก  28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต
# 9   สำนักงานเขตหนองจอก  28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต
# 12  สำนักงานเขตราชเทวี  28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต
# 14   สำนักงานเขตดินแดง  28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต
#
#    Expenditure_category                                          Item_name  \
# 8               งบลงทุน  ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเ...
# 9               งบลงทุน  ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำม...
# 12              งบลงทุน  ขุดลอกคลองส้มป่อย จากบ่อสูบน้ำคลองส้มป่อยถึงคล...
# 14              งบลงทุน  ขุดลอกลำรางศรีศุภราช จากถนนสุทธิสารวินิจฉัยถึง...
#
#     Approved_buget
# 8           447000
# 9           497000
# 12          561000
# 14          437000

# %%
mean_core28 = core_28['Approved_buget'].mean()
mean_core28
# Out:
# 485500.0

# %%
# Ans ค่าเฉลี่ยงบประมาณที่ถูกอนุมัติสูงที่สุด
print(f'Core Budget ของ เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต มีค่าเฉลี่ยงบประมาณที่ถูกอนุมัติสูงที่สุด โดยอยู่ที่ ', mean_core17, f'บาท' )
# Out:
# Core Budget ของ เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต มีค่าเฉลี่ยงบประมาณที่ถูกอนุมัติสูงที่สุด โดยอยู่ที่  1837500.0 บาท

# %% [markdown]
# ----เริ่ม คาบหน้า (27 july 2023)----

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
for row_i in range(len(data1)):
  print(data1.iloc[row_i,:])
  print('-----------------')
# Out:
# Streaming output truncated to the last 5000 lines.
# Core_budget_code                                          -
# Expenditure_category                                งบลงทุน
# Item_name               ขุดลอกคลองสาธารณะข้างหมู่บ้านเทพนคร
# Approved_buget                                       495000
# Name: 237, dtype: object
# -----------------
# Budget_resource                  งบประจำปี
# Issue_No                                 0
# Fiscal_year                             64
# Department_code                   50400000
# Department                สำนักงานเขตบางแค
# Core_budget_code                         -
# Expenditure_category               งบลงทุน
# Item_name               ขุดลอกคลองยายเพิ่ม
# Approved_buget                      439000
# Name: 238, dtype: object
# -----------------
# Budget_resource                งบประจำปี
# Issue_No                               0
# Fiscal_year                           64
# Department_code                 50400000
# Department              สำนักงานเขตบางแค
# Core_budget_code                       -
# Expenditure_category             งบลงทุน
# Item_name               ขุดลอกคลองยายกวย
# Approved_buget                    485000
# Name: 239, dtype: object
# -----------------
# Budget_resource                 งบประจำปี
# Issue_No                                0
# Fiscal_year                            64
# Department_code                  50400000
# Department               สำนักงานเขตบางแค
# Core_budget_code                        -
# Expenditure_category              งบลงทุน
# Item_name               ขุดลอกคลองเล้าหมู
# Approved_buget                     492000
# Name: 240, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            64
# Department_code                                                  50400000
# Department                                               สำนักงานเขตบางแค
# Core_budget_code                                                        -
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำกระโดงข้างหมู่บ้านศรีมงคล (ตัดซอยยิ่งเ...
# Approved_buget                                                     478000
# Name: 241, dtype: object
# -----------------
# Budget_resource                 งบประจำปี
# Issue_No                                0
# Fiscal_year                            64
# Department_code                  50400000
# Department               สำนักงานเขตบางแค
# Core_budget_code                        -
# Expenditure_category              งบลงทุน
# Item_name               ขุดลอกคลองบางด้วน
# Approved_buget                     497000
# Name: 242, dtype: object
# -----------------
# Budget_resource                                       งบประจำปี
# Issue_No                                                      0
# Fiscal_year                                                  64
# Department_code                                        50400000
# Department                                     สำนักงานเขตบางแค
# Core_budget_code                                              -
# Expenditure_category                                    งบลงทุน
# Item_name               ขุดลอกลำกระโดงในหมู่บ้านร่ำรวยนิเวศน์ 2
# Approved_buget                                           334000
# Name: 243, dtype: object
# -----------------
# Budget_resource                   งบประจำปี
# Issue_No                                  0
# Fiscal_year                              64
# Department_code                    50420000
# Department                สำนักงานเขตสายไหม
# Core_budget_code                          -
# Expenditure_category                งบลงทุน
# Item_name               ขุดลอกคลองจรเข้โพรง
# Approved_buget                      1325000
# Name: 244, dtype: object
# -----------------
# Budget_resource                     งบประจำปี
# Issue_No                                    0
# Fiscal_year                                64
# Department_code                      50420000
# Department                  สำนักงานเขตสายไหม
# Core_budget_code                            -
# Expenditure_category                  งบลงทุน
# Item_name               ขุดลอกคลองจ้าหล่าใหญ่
# Approved_buget                        1751000
# Name: 245, dtype: object
# -----------------
# Budget_resource                 งบประจำปี
# Issue_No                                0
# Fiscal_year                            64
# Department_code                  50420000
# Department              สำนักงานเขตสายไหม
# Core_budget_code                        -
# Expenditure_category              งบลงทุน
# Item_name               ขุดลอกคลองเต้าปูน
# Approved_buget                     353000
# Name: 246, dtype: object
# -----------------
# Budget_resource                   งบประจำปี
# Issue_No                                  0
# Fiscal_year                              64
# Department_code                    50430000
# Department              สำนักงานเขตคันนายาว
# Core_budget_code                          -
# Expenditure_category                งบลงทุน
# Item_name                ขุดลอกลำรางชวดด้วน
# Approved_buget                      1106600
# Name: 247, dtype: object
# -----------------
# Budget_resource                               งบประจำปี
# Issue_No                                              0
# Fiscal_year                                          64
# Department_code                                50430000
# Department                          สำนักงานเขตคันนายาว
# Core_budget_code                                      -
# Expenditure_category                            งบลงทุน
# Item_name               ขุดลอกลำรางข้างโรงเรียนคันนายาว
# Approved_buget                                   294000
# Name: 248, dtype: object
# -----------------
# Budget_resource                   งบประจำปี
# Issue_No                                  0
# Fiscal_year                              64
# Department_code                    50430000
# Department              สำนักงานเขตคันนายาว
# Core_budget_code                          -
# Expenditure_category                งบลงทุน
# Item_name               ขุดลอกลำรางยายเลิ้ง
# Approved_buget                       291000
# Name: 249, dtype: object
# -----------------
# Budget_resource                   งบประจำปี
# Issue_No                                  0
# Fiscal_year                              64
# Department_code                    50440000
# Department              สำนักงานเขตสะพานสูง
# Core_budget_code                          -
# Expenditure_category                งบลงทุน
# Item_name               ขุดลอกคลองสะพานสูง
# Approved_buget                      1601000
# Name: 250, dtype: object
# -----------------
# Budget_resource                   งบประจำปี
# Issue_No                                  0
# Fiscal_year                              64
# Department_code                    50440000
# Department              สำนักงานเขตสะพานสูง
# Core_budget_code                          -
# Expenditure_category                งบลงทุน
# Item_name                ขุดลอกคลองบัวคลี่
# Approved_buget                      3961000
# Name: 251, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            64
# Department_code                                                  50460000
# Department                                           สำนักงานเขตคลองสามวา
# Core_budget_code                                                        -
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองสามตะวันตก จากคลองสามวา ถึงคลองพระยา...
# Approved_buget                                                    6236000
# Name: 252, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            64
# Department_code                                                  50460000
# Department                                           สำนักงานเขตคลองสามวา
# Core_budget_code                                                        -
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองสี่ตะวันตก จากคลองสามวา ถึงคลองพระยา...
# Approved_buget                                                    5815000
# Name: 253, dtype: object
# -----------------
# Budget_resource                   งบประจำปี
# Issue_No                                  0
# Fiscal_year                              64
# Department_code                    50490000
# Department               สำนักงานเขตทุ่งครุ
# Core_budget_code                          -
# Expenditure_category                งบลงทุน
# Item_name               ขุดลอกคลองสะพานควาย
# Approved_buget                      2207000
# Name: 254, dtype: object
# -----------------
# Budget_resource                    งบประจำปี
# Issue_No                                   0
# Fiscal_year                               64
# Department_code                     50500000
# Department                 สำนักงานเขตบางบอน
# Core_budget_code                           -
# Expenditure_category                 งบลงทุน
# Item_name               ขุดลอกคลองรางขวาง 1
# Approved_buget                        498000
# Name: 255, dtype: object
# -----------------
# Budget_resource                    งบประจำปี
# Issue_No                                   0
# Fiscal_year                               64
# Department_code                     50500000
# Department                 สำนักงานเขตบางบอน
# Core_budget_code                           -
# Expenditure_category                 งบลงทุน
# Item_name               ขุดลอกคลองรางขวาง 2
# Approved_buget                        494000
# Name: 256, dtype: object
# -----------------
# Budget_resource                 งบประจำปี
# Issue_No                                0
# Fiscal_year                            64
# Department_code                  50500000
# Department              สำนักงานเขตบางบอน
# Core_budget_code                        -
# Expenditure_category              งบลงทุน
# Item_name                ขุดลอกลำรางข่อย
# Approved_buget                     471000
# Name: 257, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            64
# Department_code                                                  50500000
# Department                                              สำนักงานเขตบางบอน
# Core_budget_code                                                        -
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำรางซอยเอกชัย 45 จากคลองบางบอน ถึงบ้านเ...
# Approved_buget                                                     474000
# Name: 258, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            64
# Department_code                                                  50500000
# Department                                              สำนักงานเขตบางบอน
# Core_budget_code                                                        -
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำรางซอยเอกชัย 89 จากคลองบางบอน ถึงสุดเข...
# Approved_buget                                                     342000
# Name: 259, dtype: object
# -----------------
# Budget_resource                                    งบประจำปี
# Issue_No                                                   0
# Fiscal_year                                               64
# Department_code                                     50500000
# Department                                 สำนักงานเขตบางบอน
# Core_budget_code                                           -
# Expenditure_category                                 งบลงทุน
# Item_name               ขุดลอกลำกระโดงข้างซอยเอกชัย 43 แยก 2
# Approved_buget                                        472000
# Name: 260, dtype: object
# -----------------
# Budget_resource                 งบประจำปี
# Issue_No                                0
# Fiscal_year                            64
# Department_code                  50500000
# Department              สำนักงานเขตบางบอน
# Core_budget_code                        -
# Expenditure_category              งบลงทุน
# Item_name                ขุดลอกคลองนายผล
# Approved_buget                     488000
# Name: 261, dtype: object
# -----------------
# Budget_resource                  งบประจำปี
# Issue_No                                 0
# Fiscal_year                             64
# Department_code                   50500000
# Department               สำนักงานเขตบางบอน
# Core_budget_code                         -
# Expenditure_category               งบลงทุน
# Item_name               ขุดลอกคลองบางด้วน
# Approved_buget                      410000
# Name: 262, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            64
# Department_code                                                  50500000
# Department                                              สำนักงานเขตบางบอน
# Core_budget_code                                                        -
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองเนตรนุสรณ์ จากคลองบางบอนถึงสุดเขตกรุ...
# Approved_buget                                                     978000
# Name: 263, dtype: object
# -----------------
# Budget_resource                 งบประจำปี
# Issue_No                                0
# Fiscal_year                            64
# Department_code                  50500000
# Department              สำนักงานเขตบางบอน
# Core_budget_code                        -
# Expenditure_category              งบลงทุน
# Item_name                 ขุดลอกคลองควาย
# Approved_buget                     498000
# Name: 264, dtype: object
# -----------------
# Budget_resource                    งบประจำปี
# Issue_No                                   0
# Fiscal_year                               64
# Department_code                     50500000
# Department                 สำนักงานเขตบางบอน
# Core_budget_code                           -
# Expenditure_category                 งบลงทุน
# Item_name               ขุดลอกคลองโคกกะวะดี
# Approved_buget                        486000
# Name: 265, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  11000000
# Department                                               สำนักการระบายน้ำ
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองบางมะเขือ \r\nจากสถานีสูบน้ำคลองบางม...
# Approved_buget                                                    1264000
# Name: 266, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  11000000
# Department                                               สำนักการระบายน้ำ
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคูน้ำข้างโรงพยาบาลบำรุงราษฎร์\r\nจากคลอง...
# Approved_buget                                                    1316000
# Name: 267, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50090000
# Department                                            สำนักงานเขตห้วยขวาง
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำรางแยกคลองบางซื่อ จากคลองบางซื่อถึงหลั...
# Approved_buget                                                     341000
# Name: 268, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50120000
# Department                                              สำนักงานเขตบางเขน
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองกะเฉด จากซอยรามอินทรา 39 แยก 28 ถึงซ...
# Approved_buget                                                     730000
# Name: 269, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50130000
# Department                                             สำนักงานเขตมีนบุรี
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำรางแยกคลองลำนายโส ตั้งแต่ถนนบัวขาวฝั่ง...
# Approved_buget                                                     488000
# Name: 270, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50170000
# Department                                             สำนักงานเขตคลองสาน
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองวัดน้อยใหม่จากแยกบ้านแขกถึงคลองสมเด็...
# Approved_buget                                                     659000
# Name: 271, dtype: object
# -----------------
# Budget_resource                                              งบประจำปี
# Issue_No                                                             0
# Fiscal_year                                                         65
# Department_code                                               50180000
# Department                                       สำนักงานเขตบางกอกใหญ่
# Core_budget_code                                                   NaN
# Expenditure_category                                           งบลงทุน
# Item_name               ขุดลอกคลองวัดหนัง จากคลองวัดดีดวกถึงสุดเขตคลอง
# Approved_buget                                                  422300
# Name: 272, dtype: object
# -----------------
# Budget_resource                                                งบประจำปี
# Issue_No                                                               0
# Fiscal_year                                                           65
# Department_code                                                 50180000
# Department                                         สำนักงานเขตบางกอกใหญ่
# Core_budget_code                                                     NaN
# Expenditure_category                                             งบลงทุน
# Item_name               ขุดลอกคลองโรงสีจากคลองบางกอกใหญ่ถึงซอยเพชรเกษม 3
# Approved_buget                                                    498600
# Name: 273, dtype: object
# -----------------
# Budget_resource                                                งบประจำปี
# Issue_No                                                               0
# Fiscal_year                                                           65
# Department_code                                                 50180000
# Department                                         สำนักงานเขตบางกอกใหญ่
# Core_budget_code                                                     NaN
# Expenditure_category                                             งบลงทุน
# Item_name               ขุดลอกคลองบ้านแขก จากคลองบางกอกใหญ่ถึงสุดเขตคลอง
# Approved_buget                                                    495100
# Name: 274, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50180000
# Department                                          สำนักงานเขตบางกอกใหญ่
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำกระโดงแยกคลองหลังวัดราชสิทธารามจากคลอง...
# Approved_buget                                                     158700
# Name: 275, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50180000
# Department                                          สำนักงานเขตบางกอกใหญ่
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองต้นตาล(เกษจำเริญ) จากคลองบางกอกใหญ่ถ...
# Approved_buget                                                     506700
# Name: 276, dtype: object
# -----------------
# Budget_resource                     งบประจำปี
# Issue_No                                    0
# Fiscal_year                                65
# Department_code                      50190000
# Department              สำนักงานเขตบางกอกน้อย
# Core_budget_code                          NaN
# Expenditure_category                  งบลงทุน
# Item_name                  ขุดลอกคลองพิณพาทย์
# Approved_buget                        1618000
# Name: 277, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50190000
# Department                                          สำนักงานเขตบางกอกน้อย
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองทรงเทวดา จากถนนจรัญสนิทวงศ์\r\nถึงจุ...
# Approved_buget                                                     326000
# Name: 278, dtype: object
# -----------------
# Budget_resource                                            งบประจำปี
# Issue_No                                                           0
# Fiscal_year                                                       65
# Department_code                                             50200000
# Department                                       สำนักงานเขตตลิ่งชัน
# Core_budget_code                                                 NaN
# Expenditure_category                                         งบลงทุน
# Item_name               ขุดลอกคลองวัดแก้ว จากคลองชักพระถึงสุดเขตคลอง
# Approved_buget                                                123000
# Name: 279, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50200000
# Department                                            สำนักงานเขตตลิ่งชัน
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองลัดบางระมาด จากคลองบางระมาดถึงคลองลั...
# Approved_buget                                                     367000
# Name: 280, dtype: object
# -----------------
# Budget_resource                                              งบประจำปี
# Issue_No                                                             0
# Fiscal_year                                                         65
# Department_code                                               50200000
# Department                                         สำนักงานเขตตลิ่งชัน
# Core_budget_code                                                   NaN
# Expenditure_category                                           งบลงทุน
# Item_name               ขุดลอกคลองลัดถมยา จากคลองบางระมาดถึงคลองบางพรม
# Approved_buget                                                  468000
# Name: 281, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50200000
# Department                                            สำนักงานเขตตลิ่งชัน
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองลัดบางลิ่ม จากคลองลัดถมยาถึงคลองบางร...
# Approved_buget                                                     458000
# Name: 282, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50200000
# Department                                            สำนักงานเขตตลิ่งชัน
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองลัดหมุ่บ้านมหาดไทย จากคลองบางระมาดถึ...
# Approved_buget                                                     373000
# Name: 283, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50200000
# Department                                            สำนักงานเขตตลิ่งชัน
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองบางลิ่ม จากคลองบางระมาดถึงถนนหมู่บ้า...
# Approved_buget                                                     499000
# Name: 284, dtype: object
# -----------------
# Budget_resource                                               งบประจำปี
# Issue_No                                                              0
# Fiscal_year                                                          65
# Department_code                                                50200000
# Department                                          สำนักงานเขตตลิ่งชัน
# Core_budget_code                                                    NaN
# Expenditure_category                                            งบลงทุน
# Item_name               ขุดลอกคลองยายวาด จากคลองบางกอกน้อยถึงสุดเขตคลอง
# Approved_buget                                                   309000
# Name: 285, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50200000
# Department                                            สำนักงานเขตตลิ่งชัน
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองลัดยายเพิ่ม จากคลองบางพรมถึงคลองบางน้อย
# Approved_buget                                                     315000
# Name: 286, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50200000
# Department                                            สำนักงานเขตตลิ่งชัน
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองลัดวัดใหม่เทพพล จากคลองบางพรมถึงคลอง...
# Approved_buget                                                     419000
# Name: 287, dtype: object
# -----------------
# Budget_resource                              งบประจำปี
# Issue_No                                             0
# Fiscal_year                                         65
# Department_code                               50210000
# Department                        สำนักงานเขตภาษีเจริญ
# Core_budget_code                                   NaN
# Expenditure_category                           งบลงทุน
# Item_name               ขุดลอกคลองบางประทุน-บางระแนะ 2
# Approved_buget                                  406300
# Name: 288, dtype: object
# -----------------
# Budget_resource                                                งบประจำปี
# Issue_No                                                               0
# Fiscal_year                                                           65
# Department_code                                                 50230000
# Department                                        สำนักงานเขตบางขุนเทียน
# Core_budget_code                                                     NaN
# Expenditure_category                                             งบลงทุน
# Item_name               ขุดลอกคลองแยกคลองระหาญ จากคลองระหาญถึงถนนสาธารณะ
# Approved_buget                                                    598000
# Name: 289, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50230000
# Department                                         สำนักงานเขตบางขุนเทียน
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองแยกคลองระหาญจากคลองระหาญช่วงต้น (ม.ว...
# Approved_buget                                                     464000
# Name: 290, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50240000
# Department                                         สำนักงานเขตราษฎร์บูรณะ
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองบางบูนจากถนนเลียบทางด่วน\nเฉลิมมหานค...
# Approved_buget                                                     353000
# Name: 291, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50240000
# Department                                         สำนักงานเขตราษฎร์บูรณะ
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองผู้ใหญ่สังข์ จากบ้านเลขที่ 91/1\nถึง...
# Approved_buget                                                     199000
# Name: 292, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50310000
# Department                                             สำนักงานเขตบางซื่อ
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองวัดเสาหิน จากซอยวงศ์สว่าง 4 \r\nถึงร...
# Approved_buget                                                     482000
# Name: 293, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50310000
# Department                                             สำนักงานเขตบางซื่อ
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคูน้ำข้างวัดประดู่ธรรมาธิปัตย์ \r\nจากบ้...
# Approved_buget                                                     235000
# Name: 294, dtype: object
# -----------------
# Budget_resource                                      งบประจำปี
# Issue_No                                                     0
# Fiscal_year                                                 65
# Department_code                                       50350000
# Department                                  สำนักงานเขตบางพลัด
# Core_budget_code                                           NaN
# Expenditure_category                                   งบลงทุน
# Item_name               ขุดลอกคลองบุญพงศ์สา ซอยจรัญสนิทวงศ์ 40
# Approved_buget                                          296000
# Name: 295, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50400000
# Department                                               สำนักงานเขตบางแค
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองผู้ใหญ่ปลื้มและคลองเชื่อมคลองหลังวัด...
# Approved_buget                                                     485000
# Name: 296, dtype: object
# -----------------
# Budget_resource                 งบประจำปี
# Issue_No                                0
# Fiscal_year                            65
# Department_code                  50400000
# Department               สำนักงานเขตบางแค
# Core_budget_code                      NaN
# Expenditure_category              งบลงทุน
# Item_name               ขุดลอกคลองตาเทียม
# Approved_buget                     494000
# Name: 297, dtype: object
# -----------------
# Budget_resource                         งบประจำปี
# Issue_No                                        0
# Fiscal_year                                    65
# Department_code                          50400000
# Department                       สำนักงานเขตบางแค
# Core_budget_code                              NaN
# Expenditure_category                      งบลงทุน
# Item_name               ขุดลอกคลองแยกคลองยายสร้อย
# Approved_buget                             434000
# Name: 298, dtype: object
# -----------------
# Budget_resource                                                 งบประจำปี
# Issue_No                                                                0
# Fiscal_year                                                            65
# Department_code                                                  50400000
# Department                                               สำนักงานเขตบางแค
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำกระโดงตรงข้ามคลองนายอี่ (ปากทางเข้าหมู...
# Approved_buget                                                     438000
# Name: 299, dtype: object
# -----------------
# Budget_resource                   งบประจำปี
# Issue_No                                  0
# Fiscal_year                              65
# Department_code                    50480000
# Department              สำนักงานเขตทวีวัฒนา
# Core_budget_code                        NaN
# Expenditure_category                งบลงทุน
# Item_name                    ขุดลอกคลองใหม่
# Approved_buget                       316000
# Name: 300, dtype: object
# -----------------
# Budget_resource                                             งบประจำปี
# Issue_No                                                            0
# Fiscal_year                                                        65
# Department_code                                              50480000
# Department                                        สำนักงานเขตทวีวัฒนา
# Core_budget_code                                                  NaN
# Expenditure_category                                          งบลงทุน
# Item_name               ขุดลอกคลองบางตาล จากถนนกาญจนาภิเษกถึงคลองควาย
# Approved_buget                                                 493000
# Name: 301, dtype: object
# -----------------
# Budget_resource                                         งบเพิ่มเติม
# Issue_No                                                          1
# Fiscal_year                                                      64
# Department_code                                            11000000
# Department                                         สำนักการระบายน้ำ
# Core_budget_code                                                NaN
# Expenditure_category                                        งบลงทุน
# Item_name               ขุดลอกคลองจิกจากถนนรามคำแหง \r\nถึงคลองกะจะ
# Approved_buget                                               907000
# Name: 302, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  11000000
# Department                                               สำนักการระบายน้ำ
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองบ้านม้าจากคลองแสนแสบ \r\nถึงคลองประเ...
# Approved_buget                                                    4193000
# Name: 303, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  11000000
# Department                                               สำนักการระบายน้ำ
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองบางขวดจากถนนประดิษฐ์มนูธรรม\r\nถึงคล...
# Approved_buget                                                    2018000
# Name: 304, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  11000000
# Department                                               สำนักการระบายน้ำ
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองห้วยขวางจากคลองบางซื่อ\r\nถึงถนนเทีย...
# Approved_buget                                                    2460000
# Name: 305, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  11000000
# Department                                               สำนักการระบายน้ำ
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองหนองบอนจาก ปตร.หนองบอน\r\nถึงคลองปลั...
# Approved_buget                                                    5290000
# Name: 306, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  50130000
# Department                                             สำนักงานเขตมีนบุรี
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำรางโต๊ะสาว ตั้งแต่คลองแสนแสบถึงคลองแยก...
# Approved_buget                                                     483000
# Name: 307, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  50130000
# Department                                             สำนักงานเขตมีนบุรี
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำรางตาแล ตั้งแต่คลองแสนแสบถึงคลองแยกคลอ...
# Approved_buget                                                     488000
# Name: 308, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  50130000
# Department                                             สำนักงานเขตมีนบุรี
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำรางตามุด ตั้งแต่คลองแสนแสบถึงคลองแยกคล...
# Approved_buget                                                     498000
# Name: 309, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  50130000
# Department                                             สำนักงานเขตมีนบุรี
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำรางยายพร้อม ตั้งแต่คลองแสนแสบถึงคลองแย...
# Approved_buget                                                     445000
# Name: 310, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  50130000
# Department                                             สำนักงานเขตมีนบุรี
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำรางต้นสะตือ ตั้งแต่คลองลำบึงใหญ่ถึงหมู...
# Approved_buget                                                     453000
# Name: 311, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  50130000
# Department                                             สำนักงานเขตมีนบุรี
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำรางข้างวัดบำเพ็ญเหนือ ตั้งแต่คลองแสนแส...
# Approved_buget                                                     469000
# Name: 312, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  50130000
# Department                                             สำนักงานเขตมีนบุรี
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองกีบหมู (มีนบุรี) ตั้งแต่ลำรางคูคต (ม...
# Approved_buget                                                    1364000
# Name: 313, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            64
# Department_code                                                  50130000
# Department                                             สำนักงานเขตมีนบุรี
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองลำพังพวย (มีนบุรี) ตั้งแต่คลองลำไผ่เ...
# Approved_buget                                                    3280000
# Name: 314, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# ...
# Fiscal_year                                        66
# Department_code                              50350000
# Department                         สำนักงานเขตบางพลัด
# Core_budget_code                                  NaN
# Expenditure_category                          งบลงทุน
# Item_name               ขุดลอกคูน้ำซอยจรัญสนิทวงศ์ 63
# Approved_buget                                 257000
# Name: 663, dtype: object
# -----------------
# Budget_resource                                 งบเพิ่มเติม
# Issue_No                                                  1
# Fiscal_year                                              66
# Department_code                                    50350000
# Department                               สำนักงานเขตบางพลัด
# Core_budget_code                                        NaN
# Expenditure_category                                งบลงทุน
# Item_name               ขุดลอกคูน้ำแยกคลองบางบำหรุ (ออนป้า)
# Approved_buget                                       276000
# Name: 664, dtype: object
# -----------------
# Budget_resource                      งบเพิ่มเติม
# Issue_No                                       1
# Fiscal_year                                   66
# Department_code                         50350000
# Department                    สำนักงานเขตบางพลัด
# Core_budget_code                             NaN
# Expenditure_category                     งบลงทุน
# Item_name               ขุดลอกคลองวัดน้อยนางหงษ์
# Approved_buget                           1187000
# Name: 665, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            66
# Department_code                                                  50360000
# Department                                              สำนักงานเขตจอมทอง
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกคลองลัดบางสะแก (1),(2) จากคลองบางค้อและค...
# Approved_buget                                                    1581000
# Name: 666, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            66
# Department_code                                                  50360000
# Department                                              สำนักงานเขตจอมทอง
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำกระโดงสาธารณประโยชน์หลังโรงเรียนเลิศพั...
# Approved_buget                                                     181000
# Name: 667, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            66
# Department_code                                                  50360000
# Department                                              สำนักงานเขตจอมทอง
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำกระโดงสาธารณประโยชน์แยกคลองต้นไทร (1) ...
# Approved_buget                                                     206000
# Name: 668, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            66
# Department_code                                                  50360000
# Department                                              สำนักงานเขตจอมทอง
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำกระโดงสาธารณประโยชน์แยกคลองต้นไทร (2) ...
# Approved_buget                                                     140000
# Name: 669, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            66
# Department_code                                                  50360000
# Department                                              สำนักงานเขตจอมทอง
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำกระโดงสาธารณประโยชน์แยกคลองต้นไทร (3),...
# Approved_buget                                                    1388000
# Name: 670, dtype: object
# -----------------
# Budget_resource                                      งบเพิ่มเติม
# Issue_No                                                       1
# Fiscal_year                                                   66
# Department_code                                         50400000
# Department                                     สำนักงานเขตจอมทอง
# Core_budget_code                                             NaN
# Expenditure_category                                     งบลงทุน
# Item_name               ขุดลอกลำกระโดงแยกคลองบางจากล่าง (ซอย 38)
# Approved_buget                                            308000
# Name: 671, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            66
# Department_code                                                  50400000
# Department                                               สำนักงานเขตบางแค
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประ...
# Approved_buget                                                     472000
# Name: 672, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            66
# Department_code                                                  50400000
# Department                                               สำนักงานเขตบางแค
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำกระโดงแยกคลองบางขี้แก้ง (หมู่บ้านเอเวอ...
# Approved_buget                                                     492000
# Name: 673, dtype: object
# -----------------
# Budget_resource                        งบเพิ่มเติม
# Issue_No                                         1
# Fiscal_year                                     66
# Department_code                           50400000
# Department                        สำนักงานเขตบางแค
# Core_budget_code                               NaN
# Expenditure_category                       งบลงทุน
# Item_name               ขุดลอกคลองแยกคลองตาเทียม 1
# Approved_buget                              469000
# Name: 674, dtype: object
# -----------------
# Budget_resource                                               งบเพิ่มเติม
# Issue_No                                                                1
# Fiscal_year                                                            66
# Department_code                                                  50400000
# Department                                               สำนักงานเขตบางแค
# Core_budget_code                                                      NaN
# Expenditure_category                                              งบลงทุน
# Item_name               ขุดลอกลำกระโดงระหว่างซอยเพชรเกษม 43 กับ ซอยเพช...
# Approved_buget                                                     493000
# Name: 675, dtype: object
# -----------------
# Budget_resource                       งบเพิ่มเติม
# Issue_No                                        1
# Fiscal_year                                    66
# Department_code                          50400000
# Department                       สำนักงานเขตบางแค
# Core_budget_code                              NaN
# Expenditure_category                      งบลงทุน
# Item_name               ขุดลอกคลองแยกคลองยายเพิ่ม
# Approved_buget                             481000
# Name: 676, dtype: object
# -----------------
# Budget_resource                             งบเพิ่มเติม
# Issue_No                                              1
# Fiscal_year                                          66
# Department_code                                50400000
# Department                             สำนักงานเขตบางแค
# Core_budget_code                                    NaN
# Expenditure_category                            งบลงทุน
# Item_name               ขุดลอกลำกระโดงข้างหมู่บ้านวรนุช
# Approved_buget                                   492000
# Name: 677, dtype: object
# -----------------
# Budget_resource              งบเพิ่มเติม
# Issue_No                               1
# Fiscal_year                           66
# Department_code                 50400000
# Department              สำนักงานเขตบางแค
# Core_budget_code                     NaN
# Expenditure_category             งบลงทุน
# Item_name                ขุดลอกคลองตาตี่
# Approved_buget                    483000
# Name: 678, dtype: object
# -----------------
# Budget_resource                         งบเพิ่มเติม
# Issue_No                                          1
# Fiscal_year                                      66
# Department_code                            50400000
# Department                         สำนักงานเขตบางแค
# Core_budget_code                                NaN
# Expenditure_category                        งบลงทุน
# Item_name               ขุดลอกลำกระโดงข้างเดอะมอลล์
# Approved_buget                               462000
# Name: 679, dtype: object
# -----------------
# Budget_resource                           งบเพิ่มเติม
# Issue_No                                            1
# Fiscal_year                                        66
# Department_code                              50400000
# Department                           สำนักงานเขตบางแค
# Core_budget_code                                  NaN
# Expenditure_category                          งบลงทุน
# Item_name               ขุดลอกลำกระโดงข้างบ้านบางแค 2
# Approved_buget                                 499000
# Name: 680, dtype: object
# -----------------
# Budget_resource                  งบเพิ่มเติม
# Issue_No                                   1
# Fiscal_year                               66
# Department_code                     50460000
# Department              สำนักงานเขตคลองสามวา
# Core_budget_code                         NaN
# Expenditure_category                 งบลงทุน
# Item_name                   ขุดลอกลำรางตาเชย
# Approved_buget                       3559000
# Name: 681, dtype: object
# -----------------
# Budget_resource                   งบเพิ่มเติม
# Issue_No                                    1
# Fiscal_year                                66
# Department_code                      50460000
# Department               สำนักงานเขตคลองสามวา
# Core_budget_code                          NaN
# Expenditure_category                  งบลงทุน
# Item_name               ขุดลอกลำรางไทยเอราวัณ
# Approved_buget                        3494000
# Name: 682, dtype: object
# -----------------
# Budget_resource                    งบเพิ่มเติม
# Issue_No                                     1
# Fiscal_year                                 66
# Department_code                       50460000
# Department                สำนักงานเขตคลองสามวา
# Core_budget_code                           NaN
# Expenditure_category                   งบลงทุน
# Item_name               ขุดลอกคลองหนึ่งตะวันตก
# Approved_buget                         4330000
# Name: 683, dtype: object
# -----------------
# Budget_resource                  งบเพิ่มเติม
# Issue_No                                   1
# Fiscal_year                               66
# Department_code                     50460000
# Department              สำนักงานเขตคลองสามวา
# Core_budget_code                         NaN
# Expenditure_category                 งบลงทุน
# Item_name               ขุดลอกคลองสองตะวันตก
# Approved_buget                       9832000
# Name: 684, dtype: object
# -----------------
# Budget_resource                  งบเพิ่มเติม
# Issue_No                                   1
# Fiscal_year                               66
# Department_code                     50460000
# Department              สำนักงานเขตคลองสามวา
# Core_budget_code                         NaN
# Expenditure_category                 งบลงทุน
# Item_name                   ขุดลอกคลองกีบหมู
# Approved_buget                       2925000
# Name: 685, dtype: object
# -----------------
# Budget_resource                  งบเพิ่มเติม
# Issue_No                                   1
# Fiscal_year                               66
# Department_code                     50460000
# Department              สำนักงานเขตคลองสามวา
# Core_budget_code                         NaN
# Expenditure_category                 งบลงทุน
# Item_name                 ขุดลอกคลองลำกะโหลก
# Approved_buget                       3875000
# Name: 686, dtype: object
# -----------------
# Budget_resource                  งบเพิ่มเติม
# Issue_No                                   1
# Fiscal_year                               66
# Department_code                     50460000
# Department              สำนักงานเขตคลองสามวา
# Core_budget_code                         NaN
# Expenditure_category                 งบลงทุน
# Item_name                 ขุดลอกคลองผักกะเฉด
# Approved_buget                       3686000
# Name: 687, dtype: object
# -----------------
# Budget_resource                     งบเพิ่มเติม
# Issue_No                                      1
# Fiscal_year                                  66
# Department_code                        50460000
# Department                 สำนักงานเขตคลองสามวา
# Core_budget_code                            NaN
# Expenditure_category                    งบลงทุน
# Item_name               ขุดลอกคลองบึงทรายกองดิน
# Approved_buget                          2575000
# Name: 688, dtype: object
# -----------------
# Budget_resource                  งบเพิ่มเติม
# Issue_No                                   1
# Fiscal_year                               66
# Department_code                     50460000
# Department              สำนักงานเขตคลองสามวา
# Core_budget_code                         NaN
# Expenditure_category                 งบลงทุน
# Item_name                  ขุดลอกลำรางซาฟารี
# Approved_buget                        689000
# Name: 689, dtype: object
# -----------------
# Budget_resource                  งบเพิ่มเติม
# Issue_No                                   1
# Fiscal_year                               66
# Department_code                     50460000
# Department              สำนักงานเขตคลองสามวา
# Core_budget_code                         NaN
# Expenditure_category                 งบลงทุน
# Item_name                ขุดลอกลำรางตาจันทร์
# Approved_buget                        464000
# Name: 690, dtype: object
# -----------------
# Budget_resource                                       งบเพิ่มเติม
# Issue_No                                                        1
# Fiscal_year                                                    66
# Department_code                                          50500000
# Department                                      สำนักงานเขตบางบอน
# Core_budget_code                                              NaN
# Expenditure_category                                      งบลงทุน
# Item_name               ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล
# Approved_buget                                            7578000
# Name: 691, dtype: object
# -----------------

# %%
for row in data1.iterrows():
  #print(row)
  print(row[1]['Fiscal_year'])
  print('--------------')
# Out:
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 62
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 63
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 64
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 65
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------
# 66
# --------------

# %% [markdown]
# วนลูป ช่วยในการสร้าง data เพิ่ม

# %% [markdown]
# ##การสร้าง columns เพิ่ม
# ```df['ชื่อ column ใหม่'] = list of data # list of data มีจำนวนสมาชิกเท่ากับจำนวน row1 ของตาราง```

# %%
small_df
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Core_budget_code Expenditure_category  \
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 691     สำนักงานเขตบางบอน              NaN              งบลงทุน
#
#                                      Item_name  Approved_buget
# 687                         ขุดลอกคลองผักกะเฉด         3686000
# 688                    ขุดลอกคลองบึงทรายกองดิน         2575000
# 689                          ขุดลอกลำรางซาฟารี          689000
# 690                        ขุดลอกลำรางตาจันทร์          464000
# 691  ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล         7578000

# %%
small_df['ผู้รับผิดชอบ'] = ['ลุงตู่', 'ลุงตู่', 'ลุงป้อม', 'ชัชชาติ', 'พิธา']
# Out:
# <ipython-input-137-dd668cf87aac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_df['ผู้รับผิดชอบ'] = ['ลุงตู่', 'ลุงตู่', 'ลุงป้อม', 'ชัชชาติ', 'พิธา']

# %%
#small_df

# %% [markdown]
# ##การลบ columns

# %%
small_df.drop(axis=1,columns=['Core_budget_code']) ##axis คือ แกน drop axis แกน1 ##ไม่ใส่ได้ แต่มีค่า defalt
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Expenditure_category  \
# 687  สำนักงานเขตคลองสามวา              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              งบลงทุน
# 691     สำนักงานเขตบางบอน              งบลงทุน
#
#                                      Item_name  Approved_buget ผู้รับผิดชอบ
# 687                         ขุดลอกคลองผักกะเฉด         3686000       ลุงตู่
# 688                    ขุดลอกคลองบึงทรายกองดิน         2575000       ลุงตู่
# 689                          ขุดลอกลำรางซาฟารี          689000      ลุงป้อม
# 690                        ขุดลอกลำรางตาจันทร์          464000      ชัชชาติ
# 691  ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล         7578000         พิธา

# %%
#small_df.drop()

# %%
#สร้าง column ใหม่ ที่นำสาม column มารวมกัน
new_column = list()
for row in data1.iterrows():
  new_col = f"{row[1]['Department']}-{row[1]['Expenditure_category']}-{row[1]['Item_name']}"
  new_column.append(new_col)

# %%
#new_column

# %%
data1['describtion'] = new_column
data1 = data1.drop(axis=1, columns=['Department', 'Expenditure_category', 'Item_name'])

# %%
data1
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 0         งบประจำปี         0           62         11000000
# 1         งบประจำปี         0           62         11000000
# 2         งบประจำปี         0           62         11000000
# 3         งบประจำปี         0           62         11000000
# 4         งบประจำปี         0           62         11000000
# ..              ...       ...          ...              ...
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                                       Core_budget_code  Approved_buget  \
# 0    12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...         1193000
# 1    12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...         1100000
# 2    12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...         3075000
# 3    12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...         6240000
# 4    12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...         2685000
# ..                                                 ...             ...
# 687                                                NaN         3686000
# 688                                                NaN         2575000
# 689                                                NaN          689000
# 690                                                NaN          464000
# 691                                                NaN         7578000
#
#                                            describtion
# 0    สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากค...
# 1    สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียม...
# 2    สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลอง...
# 3    สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจาก...
# 4    สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลอ...
# ..                                                 ...
# 687    สำนักงานเขตคลองสามวา-งบลงทุน-ขุดลอกคลองผักกะเฉด
# 688  สำนักงานเขตคลองสามวา-งบลงทุน-ขุดลอกคลองบึงทราย...
# 689     สำนักงานเขตคลองสามวา-งบลงทุน-ขุดลอกลำรางซาฟารี
# 690   สำนักงานเขตคลองสามวา-งบลงทุน-ขุดลอกลำรางตาจันทร์
# 691  สำนักงานเขตบางบอน-งบลงทุน-ขุดลอกคลองบางบอนต่อจ...
#
# [692 rows x 7 columns]

# %%
this_data = data_covid[['sex','age','province_of_onset']]
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
for each_row in this_data.iterrows():
    # print(each_row)
    # print(each_row[1])
    # print(each_row[1]['sex'])
    if (each_row[1]['age'] <= 20) and (each_row[1]['province_of_onset'] == 'ขอนแก่น'):
        print(each_row)
# Out:
# (1466, sex                      ชาย
# age                       19
# province_of_onset    ขอนแก่น
# Name: 1466, dtype: object)
# (9333, sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 9333, dtype: object)
# (9334, sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object)
# (10610, sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 10610, dtype: object)
# (11517, sex                      ชาย
# age                       12
# province_of_onset    ขอนแก่น
# Name: 11517, dtype: object)
# (11697, sex                     หญิง
# age                       17
# province_of_onset    ขอนแก่น
# Name: 11697, dtype: object)

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %%
for each_row in range(this_data.shape[0]):
    if (this_data.iloc[each_row,1] <= 20) and (this_data.iloc[each_row,2] == 'ขอนแก่น'):  #each_row คือ ตัวเลข
        print(each_row)
        print(this_data.iloc[each_row,:])
# Out:
# 1466
# sex                      ชาย
# age                       19
# province_of_onset    ขอนแก่น
# Name: 1466, dtype: object
# 9333
# sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 9333, dtype: object
# 9334
# sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object
# 10610
# sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 10610, dtype: object
# 11517
# sex                      ชาย
# age                       12
# province_of_onset    ขอนแก่น
# Name: 11517, dtype: object
# 11697
# sex                     หญิง
# age                       17
# province_of_onset    ขอนแก่น
# Name: 11697, dtype: object

# %% [markdown]
# ## Quiz ตัดตารางออกมาเฉพาะปี 2021 ```announce_date``` ในปี 2021
#
# **Hint**
# *   วนลูปหา index ของปี 2021
# *   ตัดตารางมาเฉพาะ ปี 2021

# %%
TF=list()
for each_row in data_covid.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2021':
        TF.append(True)
    else:
        TF.append(False)

data_covid[TF].head()
# Out:
#        No.  ...                                               risk
# 6884  6885  ...                                  Cluster สมุทรสาคร
# 6885  6886  ...                                      Cluster ระยอง
# 6886  6887  ...                                        สถานบันเทิง
# 6887  6888  ...                                  Cluster สมุทรสาคร
# 6888  6889  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
#
# [5 rows x 10 columns]

# %%
TF
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  ...]

# %% [markdown]
# ### HW กลุ่ม 2 || เลือกข้อมูลมาเฉพาะวัน announce_date เป็นวันที่ 1-20

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
data_covid.describe()
# Out:
#                 No.          age
# count  12653.000000  8881.000000
# mean    6327.000000    38.054748
# std     3652.750813    15.125178
# min        1.000000     0.100000
# 25%     3164.000000    27.000000
# 50%     6327.000000    36.000000
# 75%     9490.000000    48.000000
# max    12653.000000    97.000000

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
data_covid[data_covid['sex']=='ชาย']['age'].mean()
# Out:
# 39.46076940331987

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
#
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
