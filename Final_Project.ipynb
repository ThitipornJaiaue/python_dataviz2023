# %% [markdown]
# <a href="https://colab.research.google.com/github/ThitipornJaiaue/python_dataviz2023/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Haloooo testtt')
# Out:
# Haloooo testtt

# %%
#เชื่อม google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#เข้าไป path ใน google drive
import os
os.chdir('/content/drive/Shareddrives')

# !pwd #เช็ค path ที่กำลังทำงานอยู่
# Out:
# /content/drive/Shareddrives

# %%
import os
os.chdir('/content/drive/Shareddrives/Project_DataViz23data')

# %%
import pandas as pd

# %%
ect_66 = pd.read_excel('/content/drive/Shareddrives/Project_DataViz23data/ectreport66.xlsx', header = 25)
ect_66
# Out:
#                            info_province              province_id   string  \
# 0                          info_province                  prov_id   string
# 1                          info_province                 province   string
# 2                          info_province               abbre_thai   string
# 3                          info_province                      eng   string
# 4                          info_province      total_vote_stations   number
# 5                          info_province    total_registered_vote   number
# 6           result_constituencies_status                  prov_id   string
# 7           result_constituencies_status                  cons_id   string
# 8           result_constituencies_status                 turn_out   number
# 9           result_constituencies_status         percent_turn_out   number
# 10          result_constituencies_status    counted_vote_stations   number
# ...

# %%
# !ls
# Out:
# ectreport66.xlsx  table_merge_result.csv

# %% [markdown]
# # 🔗Database
#
# [Google drive link for Database](https://drive.google.com/drive/folders/18Xsh2jEf7s2bTQY_0lHhOXXxuyM_3_9V?usp=sharing)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 🔗Open CSV file 🫣
# ```
# import pandas as pd
# file_name = 'ectreport66.xlsx'
# sheet = 'sheet_name'
# df = pd.read_excel(io=file_name, sheet_name=sheet)
# print(df)
# ```

# %%
import pandas as pd

file_name = '/content/drive/Shareddrives/Project_DataViz23data/ectreport66.xlsx' # ชื่อไฟล์ xlsx
dfs = pd.ExcelFile(file_name) # คำสั่งอ่านไฟล์ xlsx

dfs.sheet_names # คำสั่งเช็คว่าในไฟล์ xlsx มี seet ย่อย ในไฟล์ชื่อว่าอะไรบ้าง
# Out:
# ['Schema',
#  'result_constituencies_PartyList',
#  'result_constituencies_Candidate',
#  'result_constituencies_status',
#  'info_province',
#  'info_party_overview',
#  'info_constituency',
#  'Candidate_Constituency',
#  'Candidate_PartyList',
#  'Candidate_PM']

# %%
import pandas as pd

file_name = '/content/drive/Shareddrives/Project_DataViz23data/ectreport66.xlsx' # ชื่อไฟล์ xlsx
dfs = pd.ExcelFile(file_name) # คำสั่งอ่านไฟล์ xlsx

dfs.sheet_names # คำสั่งเช็คว่าในไฟล์ xlsx มี seet ย่อย ในไฟล์ชื่อว่าอะไรบ้าง
# Out:
# ['Schema',
#  'result_constituencies_PartyList',
#  'result_constituencies_Candidate',
#  'result_constituencies_status',
#  'info_province',
#  'info_party_overview',
#  'info_constituency',
#  'Candidate_Constituency',
#  'Candidate_PartyList',
#  'Candidate_PM']

# %%
# select sheet page by sheet name
Schema = dfs.parse('Schema')
result_constituencies_PartyList = dfs.parse('result_constituencies_PartyList')
result_constituencies_Candidate = dfs.parse('result_constituencies_Candidate')
result_constituencies_status = dfs.parse('result_constituencies_status')
info_province = dfs.parse('info_province')
info_party_overview = dfs.parse('info_party_overview')
info_constituency = dfs.parse('info_constituency')
Candidate_constituency = dfs.parse('Candidate_Constituency')
Candidate_partyList = dfs.parse('Candidate_PartyList')
Candidate_pm = dfs.parse('Candidate_PM')

# %%
 Candidate_pm
# Out:
#     party_no                                              name  \
# 0          2                                 นายสุรทิน พิจารณ์
# 1          4                          นายบัญชา เดชเจริญศิริกุล
# 2          5                         นายเชาวฤทธิ์ ขจรพงศ์กีรติ
# 3          7                               นายอนุทิน ชาญวีรกูล
# 4          9                           นายชัยยพล พสุรัตน์บรรจง
# ..       ...                                               ...
# 57        63                               นางสาวภคมน วงศ์ใหญ่
# 58        63                                  นายคณิศร สมมะลวน
# 59        63                                   นายหรรษธร ณรงค์
# 60        65  ผู้ช่วยศาสตราจารย์ (พิเศษ) อัครนันท์ อริยศรีพงษ์
# 61        67                         นายเกียรติภูมิ สิริพันธุ์
#
#                                             image_url
# 0   https://cdn.ectreport.com/images/pm_candidates...
# 1   https://cdn.ectreport.com/images/pm_candidates...
# ...

# %% [markdown]
# # 🔗Explore database

# %%
Schema.head()  # Metadata: sheet page สำหรับอธิบาย ตัวแปรใน sheet อื่นๆ
# Out:
#                     Sheet           Column Data Type  \
# 0  Candidate_Constituency        mp_app_id    string
# 1  Candidate_Constituency        mp_app_no    number
# 2  Candidate_Constituency  mp_app_party_id    string
# 3  Candidate_Constituency      mp_app_name    string
# 4  Candidate_Constituency        image_url    string
#
#                      Description  \
# 0          รหัสผู้สมัคร ส.ส. เขต
# 1       หมายเลขผู้สมัคร ส.ส. เขต
# 2  สังกัดพรรคตามรหัสพรรคการเมือง
# 3                   ชื่อผู้สมัคร
# 4            ลิงก์รูปภาพผู้สมัคร
#
#                                              Example
# 0                                            BKK_1_1
# 1                                                  1
# 2                                                701
# 3                                    นายทดสอบ สามารถ
# 4  https://ectdatastorage.blob.core.windows.net/d...

# %%
print(result_constituencies_PartyList.isnull().any()) # เช็คค่าว่าง Null
result_constituencies_PartyList.head()
# Out:
# cons_id                    False
# party_id                   False
# party_list_vote            False
# party_list_vote_percent    False
# dtype: bool
#   cons_id  party_id  party_list_vote  party_list_vote_percent
# 0   ACR_1       701             4550                  4.30977
# 1   ACR_1       702              185                  0.17523
# 2   ACR_1       703               67                  0.06346
# 3   ACR_1       705            33576                 31.80328
# 4   ACR_1       706              132                  0.12503

# %%
print(result_constituencies_Candidate.isnull().any()) # เช็คค่าว่าง Null
result_constituencies_Candidate.head()
# Out:
# cons_id                False
# mp_app_id              False
# mp_app_rank            False
# mp_app_vote            False
# mp_app_vote_percent    False
# party_id               False
# dtype: bool
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761

# %%
print(result_constituencies_status.isnull().any()) # เช็คค่าว่าง Null
result_constituencies_status.head()
# Out:
# prov_id                  False
# cons_id                  False
# turn_out                 False
# percent_turn_out         False
# counted_vote_stations    False
# percent_count            False
# pause_report             False
# dtype: bool
#   prov_id cons_id  turn_out  percent_turn_out  counted_vote_stations  \
# 0     ACR   ACR_1    105574          72.60136                    310
# 1     ACR   ACR_2    111813          71.70350                    331
# 2     ATG   ATG_1     89756          80.19872                    239
# 3     ATG   ATG_2     91466          81.13075                    253
# 4     AYA   AYA_1    110317          79.55591                    226
#
#    percent_count  pause_report
# 0          100.0         False
# 1          100.0         False
# 2          100.0         False
# 3          100.0         False
# 4          100.0         False

# %%
print(info_province.isnull().any()) # เช็คค่าว่าง Null
info_province.head()
# Out:
# province_id              False
# prov_id                  False
# province                 False
# eng                      False
# abbre_thai               False
# total_registered_vote    False
# total_vote_stations      False
# dtype: bool
#    province_id prov_id         province                       eng abbre_thai  \
# 0           37     ACR       อำนาจเจริญ             AMNAT CHAROEN         อจ
# 1           15     ATG          อ่างทอง                 ANG THONG         อท
# 2           14     AYA  พระนครศรีอยุธยา  PHRA NAKHON SI AYUTTHAYA         อย
# 3           10     BKK    กรุงเทพมหานคร                   BANGKOK        กทม
# 4           38     BKN           บึงกาฬ                 BUENG KAN         บก
#
#    total_registered_vote  total_vote_stations
# 0                 301354                  641
# 1                 224656                  492
# 2                 664431                 1060
# 3                4479155                 6360
# ...

# %%
print(Candidate_constituency.isnull().any()) # เช็คค่าว่าง Null
Candidate_constituency.head()
# Out:
# mp_app_id          False
# mp_app_name        False
# mp_app_no          False
# mp_app_party_id    False
# image_url          False
# dtype: bool
#   mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0   ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2  ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3  ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4  ACR_1_13        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# 1  https://cdn.ectreport.com/images/mp_candidates...
# 2  https://cdn.ectreport.com/images/mp_candidates...
# 3  https://cdn.ectreport.com/images/mp_candidates...
# 4  https://cdn.ectreport.com/images/mp_candidates...

# %%
print(Candidate_partyList.isnull().any()) # เช็คค่าว่าง Null
Candidate_partyList.head()
# Out:
# party_no     False
# list_no      False
# name         False
# image_url    False
# dtype: bool
#    party_no  list_no                    name  \
# 0         1        1   นายกฤดิทัช แสงธนโยธิน
# 1         1        2     นายสุปรีย์ แสงสว่าง
# 2         1        3     นายธนภัท อุทุมพันธ์
# 3         1        4          นายทิวา ขำศิริ
# 4         1        5  นายปิยพัชร์ อ่ำสำอางค์
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/candidates/นา...
# 1  https://cdn.ectreport.com/images/candidates/นา...
# 2  https://cdn.ectreport.com/images/candidates/นา...
# 3  https://cdn.ectreport.com/images/candidates/นา...
# 4  https://cdn.ectreport.com/images/candidates/นา...

# %%
print(Candidate_pm.isnull().any()) # เช็คค่าว่าง Null
Candidate_pm.head()
# Out:
# party_no     False
# name         False
# image_url    False
# dtype: bool
#    party_no                       name  \
# 0         2          นายสุรทิน พิจารณ์
# 1         4   นายบัญชา เดชเจริญศิริกุล
# 2         5  นายเชาวฤทธิ์ ขจรพงศ์กีรติ
# 3         7        นายอนุทิน ชาญวีรกูล
# 4         9    นายชัยยพล พสุรัตน์บรรจง
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/pm_candidates...
# 1  https://cdn.ectreport.com/images/pm_candidates...
# 2  https://cdn.ectreport.com/images/pm_candidates...
# 3  https://cdn.ectreport.com/images/pm_candidates...
# 4  https://cdn.ectreport.com/images/pm_candidates...

# %% [markdown]
# ### กรณีข้อมูลมีค่าว่าง

# %% [markdown]
# ####  info_party_overview table

# %%
print(info_party_overview.isnull().any()) # เช็คค่าว่าง Null
info_party_overview.head()
# Out:
# id          False
# party_no     True
# name        False
# abbr        False
# color       False
# logo_url    False
# dtype: bool
#     id  party_no           name  abbr    color  \
# 0  701      26.0   ประชาธิปัตย์  ปชป.  #06aff3
# 1  702      63.0     ประชากรไทย  ปชท.  #0f41ce
# 2  703      60.0   ความหวังใหม่  ควม.  #e6b750
# 3  705      29.0       เพื่อไทย   พท.  #da3731
# 4  706      14.0  ชาติพัฒนากล้า  ชพก.  #233e8a
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1  https://cdn.ectreport.com/images/logos/ประชากร...
# 2  https://cdn.ectreport.com/images/logos/ความหวั...
# 3  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4  https://cdn.ectreport.com/images/logos/ชาติพัฒ...

# %%
info_party_overview[info_party_overview['party_no'].isnull()] #แสดง row ที่มี party_no ว่าง
# party_no คือ เลขพรรคการเมืองในบัตรเลือกตั้ง ส.ส. บัญชีรายชื่อ
# ประชาสามัคคี	- 99
# พลังบูรพา - 99
# รักษ์ธรรม - 99
# Out:
#      id  party_no          name  abbr    color  \
# 9   711       NaN  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       NaN     พลังบูรพา   พบ.  #4696d6
# 17  720       NaN     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %% [markdown]
# [ref// เลือกตั้ง 2566 : เช็กเบอร์ "พรรคการเมือง 2566" แบบบัญชีรายชื่อ ](https://www.pptvhd36.com/%E0%B9%80%E0%B8%A5%E0%B8%B7%E0%B8%AD%E0%B8%81%E0%B8%95%E0%B8%B1%E0%B9%89%E0%B8%872566/%E0%B8%A3%E0%B8%B2%E0%B8%A2%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9C%E0%B8%B9%E0%B9%89%E0%B8%AA%E0%B8%A1%E0%B8%B1%E0%B8%84%E0%B8%A3/%E0%B9%81%E0%B8%9A%E0%B8%9A%E0%B8%9A%E0%B8%B1%E0%B8%8D%E0%B8%8A%E0%B8%B5%E0%B8%A3%E0%B8%B2%E0%B8%A2%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD)

# %%
# แทนค่าว่างด้วยหมายเลข 99
info_party_overview['party_no'] = info_party_overview['party_no'].fillna(99)

# %%
print(info_party_overview.isnull().any()) # เช็คค่าว่าง Null อีกรอบ
info_party_overview.head()
# Out:
# id          False
# party_no    False
# name        False
# abbr        False
# color       False
# logo_url    False
# dtype: bool
#     id  party_no           name  abbr    color  \
# 0  701      26.0   ประชาธิปัตย์  ปชป.  #06aff3
# 1  702      63.0     ประชากรไทย  ปชท.  #0f41ce
# 2  703      60.0   ความหวังใหม่  ควม.  #e6b750
# 3  705      29.0       เพื่อไทย   พท.  #da3731
# 4  706      14.0  ชาติพัฒนากล้า  ชพก.  #233e8a
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1  https://cdn.ectreport.com/images/logos/ประชากร...
# 2  https://cdn.ectreport.com/images/logos/ความหวั...
# 3  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4  https://cdn.ectreport.com/images/logos/ชาติพัฒ...

# %% [markdown]
# ####  info_constituency table

# %%
print(info_constituency.isnull().any()) # เช็คค่าว่าง Null
info_constituency.head()
# Out:
# cons_id                False
# cons_no                False
# prov_id                False
# registered_vote        False
# total_vote_stations    False
# zone                    True
# dtype: bool
#   cons_id  cons_no prov_id  registered_vote  total_vote_stations  \
# 0   ACR_1        1     ACR           145416                  310
# 1   ACR_1        1     ACR           145416                  310
# 2   ACR_2        2     ACR           155938                  331
# 3   ACR_2        2     ACR           155938                  331
# 4   ACR_2        2     ACR           155938                  331
#
#                    zone
# 0  อำเภอเมืองอำนาจเจริญ
# 1         อำเภอหัวตะพาน
# 2       อำเภอเสนางคนิคม
# 3          อำเภอชานุมาน
# 4      อำเภอปทุมราชวงศา

# %%
info_constituency[info_constituency['zone'].isnull()] #แสดง row ที่มี party_no ว่าง
# zone คือ อาณาเขตการปกครองของเขตเลือกตั้ง
# RNG - ระนอง // มีเขตเดียว อำเภอเมืองระนอง
# SBR - สิงห์บุรี // อำเภอเมืองสิงห์บุรี
# SKM - สมุทรสงคราม // อำเภอเมืองสมุทรสงคราม
# TRT - ตราด  // อำเภอเมืองตราด
# Out:
#      cons_id  cons_no prov_id  registered_vote  total_vote_stations zone
# 804    RNG_1        1     RNG           140024                  209  NaN
# 817    SBR_1        1     SBR           168055                  213  NaN
# 839    SKM_1        1     SKM           156558                  257  NaN
# 1037   TRT_1        1     TRT           175112                  314  NaN

# %% [markdown]
# [RNG - ระนอง](https://www.itax.in.th/media/%E0%B9%80%E0%B8%82%E0%B8%95%E0%B9%80%E0%B8%A5%E0%B8%B7%E0%B8%AD%E0%B8%81%E0%B8%95%E0%B8%B1%E0%B9%89%E0%B8%87-2566-%E0%B8%A3%E0%B8%B0%E0%B8%99%E0%B8%AD%E0%B8%87/)
#
# [SBR - สิงห์บุรี](https://www.itax.in.th/media/%E0%B9%80%E0%B8%82%E0%B8%95%E0%B9%80%E0%B8%A5%E0%B8%B7%E0%B8%AD%E0%B8%81%E0%B8%95%E0%B8%B1%E0%B9%89%E0%B8%87-2566-%E0%B8%AA%E0%B8%B4%E0%B8%87%E0%B8%AB%E0%B9%8C%E0%B8%9A%E0%B8%B8%E0%B8%A3%E0%B8%B5/)
#
# [SKM - สมุทรสงคราม](https://www.itax.in.th/media/%E0%B9%80%E0%B8%82%E0%B8%95%E0%B9%80%E0%B8%A5%E0%B8%B7%E0%B8%AD%E0%B8%81%E0%B8%95%E0%B8%B1%E0%B9%89%E0%B8%87-2566-%E0%B8%AA%E0%B8%A1%E0%B8%B8%E0%B8%97%E0%B8%A3%E0%B8%AA%E0%B8%87%E0%B8%84%E0%B8%A3/)
#
# [TRT - ตราด](https://www.itax.in.th/media/%E0%B9%80%E0%B8%82%E0%B8%95%E0%B9%80%E0%B8%A5%E0%B8%B7%E0%B8%AD%E0%B8%81%E0%B8%95%E0%B8%B1%E0%B9%89%E0%B8%87-2566-%E0%B8%95%E0%B8%A3%E0%B8%B2%E0%B8%94/)

# %%
import numpy as np
# แทนค่าว่าง
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'RNG', 'อำเภอเมืองระนอง', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'SBR', 'อำเภอเมืองสิงห์บุรี', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'SKM', 'อำเภอเมืองสมุทรสงคราม', info_constituency['zone'])
info_constituency['zone'] = np.where(info_constituency['prov_id'] == 'TRT', 'อำเภอเมืองตราด', info_constituency['zone'])

# %%
print(info_constituency.isnull().any()) # เช็คค่าว่าง Null อีกรอบ
info_constituency.head()
# Out:
# cons_id                False
# cons_no                False
# prov_id                False
# registered_vote        False
# total_vote_stations    False
# zone                   False
# dtype: bool
#   cons_id  cons_no prov_id  registered_vote  total_vote_stations  \
# 0   ACR_1        1     ACR           145416                  310
# 1   ACR_1        1     ACR           145416                  310
# 2   ACR_2        2     ACR           155938                  331
# 3   ACR_2        2     ACR           155938                  331
# 4   ACR_2        2     ACR           155938                  331
#
#                    zone
# 0  อำเภอเมืองอำนาจเจริญ
# 1         อำเภอหัวตะพาน
# 2       อำเภอเสนางคนิคม
# 3          อำเภอชานุมาน
# 4      อำเภอปทุมราชวงศา

# %% [markdown]
# # 🔗 simple query database
#
# ### ข้อมูลที่เราต้องการ
#
# *   จำนวนผู้มีสิทธิเลือกตั้ง
# *   จำนวนผู้มาใช้สิทธิ์ทั้งหมด
# *   รวมคะแนนเลือกตั้งทั้งหมด
# *   ร้อยละของผู้ที่มาใช้สิทธิเลือกตั้ง
# *   จำนวนหน่วยเลือกตั้งทั้งหมด
# *  จำนวน

# %%
# จำนวนผู้มีสิทธิเลือกตั้ง
info_constituency['registered_vote'].sum()
# Out:
# 148739554

# %%
# จำนวนผู้มาใช้สิทธิ์ทั้งหมด
result_constituencies_status['turn_out'].sum()
# Out:
# 39284752

# %%
# รวมคะแนนเลือกตั้งทั้งหมด
info_constituency['total_vote_stations'].sum()
# Out:
# 282776

# %%
# ร้อยละของผู้ที่มาใช้สิทธิเลือกตั้งทั้งหมด
result_constituencies_status['percent_turn_out'].mean()
# Out:
# 75.165671125

# %%
# รวมคะแนนเลือกตั้งทั้งหมด
result_constituencies_Candidate['mp_app_vote'].sum()
# Out:
# 36595160

# %% [markdown]
# # 🔗 1-2 midterm examination

# %% [markdown]
# ###  1) หา สส แบบแบ่งเขตและพรรคที่สังกัด ที่ได้รับคะแนนเลือกตั้งมากที่สุด 10 อันดับแรก (20 คะแนน)

# %%
# Table 1 ส.ส. เขต
Candidate_constituency.head()
# Out:
#   mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0   ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2  ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3  ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4  ACR_1_13        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# 1  https://cdn.ectreport.com/images/mp_candidates...
# 2  https://cdn.ectreport.com/images/mp_candidates...
# 3  https://cdn.ectreport.com/images/mp_candidates...
# 4  https://cdn.ectreport.com/images/mp_candidates...

# %%
# Table 2 คะแนนเลือกตั้ง ----------------------------------------main
result_constituencies_Candidate.head()
# Out:
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761

# %%
# Table 3 พรรคที่สังกัด
info_party_overview.head()
# Out:
#     id  party_no           name  abbr    color  \
# 0  701      26.0   ประชาธิปัตย์  ปชป.  #06aff3
# 1  702      63.0     ประชากรไทย  ปชท.  #0f41ce
# 2  703      60.0   ความหวังใหม่  ควม.  #e6b750
# 3  705      29.0       เพื่อไทย   พท.  #da3731
# 4  706      14.0  ชาติพัฒนากล้า  ชพก.  #233e8a
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1  https://cdn.ectreport.com/images/logos/ประชากร...
# 2  https://cdn.ectreport.com/images/logos/ความหวั...
# 3  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4  https://cdn.ectreport.com/images/logos/ชาติพัฒ...

# %%
# เชื่อมตารางเพื่อ keep ข้อมูลชื่อ สส และ ชื่อ พรรคที่สังกัด
result_constituencies_Candidate['mp_app_name'] = result_constituencies_Candidate['mp_app_id'].map(Candidate_constituency.set_index('mp_app_id')['mp_app_name'])
result_constituencies_Candidate['party_name'] = result_constituencies_Candidate['party_id'].map(info_party_overview.set_index('id')['name'])

# %%
result_constituencies_Candidate.head()
# จำนวนคะแนนเสียง ส.ส. เขตที่ได้ - mp_app_vote
# Out:
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name       party_name
# 0   นางสาวปิยะมาศ บัวแก้ว    ชาติพัฒนากล้า
# 1  นางสุขสมรวย วันทนียกุล        ภูมิใจไทย
# 2     นายการันต์ ลุนพันธ์  ประชาธิปไตยใหม่
# 3          นายไสว ผลาวงศ์          คลองไทย
# 4        นายสงบ โสภิพันธ์    พลังสังคมใหม่

# %%
table = result_constituencies_Candidate.sort_values(by=['cons_id', 'mp_app_vote_percent'], ascending=False).reset_index()
table
# Out:
#       index cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      4776   YST_3   YST_3_5            1        37946             36.30085
# 1      4773   YST_3   YST_3_2            2        25205             24.11223
# 2      4780   YST_3   YST_3_9            3        14502             13.87326
# 3      4771   YST_3  YST_3_10            4        13483             12.89844
# 4      4775   YST_3   YST_3_4            5         4957              4.74209
# ...     ...     ...       ...          ...          ...                  ...
# 4776      0   ACR_1   ACR_1_1            9          459              0.43477
# 4777      5   ACR_1   ACR_1_2           10          234              0.22165
# 4778      4   ACR_1  ACR_1_13           11          212              0.20081
# 4779      3   ACR_1  ACR_1_12           12          127              0.12029
# 4780      2   ACR_1  ACR_1_11           13          126              0.11935
#
# ...

# %%
cons_id = list(set(table['cons_id']))
res = pd.DataFrame()
for i in range(len(cons_id)):
  df = result_constituencies_Candidate[result_constituencies_Candidate['cons_id'] == cons_id[i]]
  df = df.sort_values(by='mp_app_vote', ascending=False)[['cons_id', 'mp_app_name', 'party_name', 'mp_app_vote_percent', 'mp_app_vote']].iloc[0:1]
  res = res.append(df)
# Out:
# <ipython-input-40-3e1943bc7fb3>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res = res.append(df)
# <ipython-input-40-3e1943bc7fb3>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res = res.append(df)
# <ipython-input-40-3e1943bc7fb3>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res = res.append(df)
# <ipython-input-40-3e1943bc7fb3>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res = res.append(df)
# <ipython-input-40-3e1943bc7fb3>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res = res.append(df)
# ...

# %%
res.sort_values(by='mp_app_vote', ascending=False).iloc[0:10]# คะแนนเลือกตั้งมากที่สุด 10 อันดับแรก
# Out:
#      cons_id                mp_app_name      party_name  mp_app_vote_percent  \
# 4301   TRG_2             นายทวี สุระบาล    พลังประชารัฐ             60.29103
# 4358  UBN_10       นายสมศักดิ์ บุญประชม  เพื่อไทรวมพลัง             62.27446
# 960    CMI_4     นางสาวพุธิตา ชัยอนันต์         ก้าวไกล             54.01387
# 1077   CPM_2      นายเชิงชาย ชาลีรินทร์        เพื่อไทย             63.43832
# 3335   RET_5      นางสาวจิราพร สินธุไพร        เพื่อไทย             69.34758
# 2171  NMA_11  นายอาทิตย์ หวังศุภกิจโกศล        เพื่อไทย             58.86831
# 3910   SPK_5          นางสาวนิตยา มีศรี         ก้าวไกล             50.24547
# 1741   LPN_1  นายวิทวิสิทธิ์ ปันสวนปลูก         ก้าวไกล             41.13582
# 1962   NAN_2          นายชลน่าน ศรีแก้ว        เพื่อไทย             55.10872
# 1579   KSN_1        นายวิรัช พิมพะนิตย์        เพื่อไทย             59.80965
#
#       mp_app_vote
# 4301        63185
# 4358        63127
# 960         62009
# 1077        61414
# 3335        61288
# ...

# %%
# result_constituencies_Candidate.sort_values(by='mp_app_vote_percent', ascending=False)[['mp_app_name', 'party_name', 'mp_app_vote_percent', 'mp_app_vote']].iloc[0:10] # คะแนนเลือกตั้งมากที่สุด 10 อันดับแรก

# %% [markdown]
# ### 2) หา สส แบบแบ่งเขตและพรรคที่สังกัด ที่ได้คะแนนเลือกตั้งน้อยที่สุด N อันดับ โดยที่ N คือเศษที่ได้จากการหาร รหัสนักศึกษา 2 ตัวสุดท้ายด้วย เลข 5 ยกเว้นคนที่เศษเป็น 0 ให้ N=5 ตัวอย่าง เช่น IDxxxxxx13 N = 3 (30 คะแนน)

# %%
N = 13 % 5 # สมมติ  รหัสนักศึกษา 2 ตัวสุดท้าย เท่ากับ 13
N # เศษ
# Out:
# 3

# %%
res.sort_values(by='mp_app_vote', ascending=True).iloc[0:N]
# Out:
#      cons_id                     mp_app_name       party_name  \
# 3052   PRI_3                  นายสุนทร คมคาย          ก้าวไกล
# 2728   PBI_3     จ่าอากาศเอกอภิชาติ แก้วโกศล  รวมไทยสร้างชาติ
# 3140   PTN_1  ผู้ช่วยศาสตราจารย์วรวิทย์ บารู        ประชาชาติ
#
#       mp_app_vote_percent  mp_app_vote
# 3052              4.15149         4218
# 2728             10.52914        11597
# 3140             18.52324        13938

# %% [markdown]
# # 🔗 รวมตารางเพื่อนำไปทำ Dashbroad
#
# *   จำนวนโหวตที่จังหวัดนั้นโหวตให้พรรคการเมือง
# *   ผลตามจังหวัดแบบภาพรวม // Top-5
# *   จำนวนผู้มาใช้สิทธิ์
# *   ร้อยละคะแนนเสียง ส.ส. เขตของพรรคนั้นต่อจำนวนผู้ใช้สิทธิ์ทั้งหมด
# *   ผลแบบภาพรวม ตามพรรคที่ได้คะแนนอันดับ // Top-5
# *   เรียงลำดับจังหวัดที่มีผู้มีสิทธิเลือกตั้งมากที่สุด
# *   จำนวนที่ออกมาเลือกตั้ง
# *   ร้อยละของผู้ออกมาใช้สิทธิ์
# *   พรรคการเมืองที่จังหวัดนั้นโหวตให้มากที่สุด

# %%
# เรียกตารางนี้ใหม่ เพราะพึ่งเชื่อมตารางไป ใน 1-2 midterm examination
result_constituencies_Candidate = dfs.parse('result_constituencies_Candidate')

# %%
# ตารางจังหวัด (1)
info_province.head(3)
# Out:
#    province_id prov_id         province                       eng abbre_thai  \
# 0           37     ACR       อำนาจเจริญ             AMNAT CHAROEN         อจ
# 1           15     ATG          อ่างทอง                 ANG THONG         อท
# 2           14     AYA  พระนครศรีอยุธยา  PHRA NAKHON SI AYUTTHAYA         อย
#
#    total_registered_vote  total_vote_stations
# 0                 301354                  641
# 1                 224656                  492
# 2                 664431                 1060

# %%
# ตารางเขตเลือกตั้ง (2)
info_constituency.head(3)
# Out:
#   cons_id  cons_no prov_id  registered_vote  total_vote_stations  \
# 0   ACR_1        1     ACR           145416                  310
# 1   ACR_1        1     ACR           145416                  310
# 2   ACR_2        2     ACR           155938                  331
#
#                    zone
# 0  อำเภอเมืองอำนาจเจริญ
# 1         อำเภอหัวตะพาน
# 2       อำเภอเสนางคนิคม

# %%
# ตารางผลการเลือกตั้ง (3)
result_constituencies_Candidate.head(3)
# Out:
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712

# %%
# ผู้มาใช้สิทธิ์เลือกตั้ง (4)
result_constituencies_status.head(3)
# Out:
#   prov_id cons_id  turn_out  percent_turn_out  counted_vote_stations  \
# 0     ACR   ACR_1    105574          72.60136                    310
# 1     ACR   ACR_2    111813          71.70350                    331
# 2     ATG   ATG_1     89756          80.19872                    239
#
#    percent_count  pause_report
# 0          100.0         False
# 1          100.0         False
# 2          100.0         False

# %%
# ชื่อพรรคที่สังกัด (5)
info_party_overview.head(3)
# Out:
#     id  party_no          name  abbr    color  \
# 0  701      26.0  ประชาธิปัตย์  ปชป.  #06aff3
# 1  702      63.0    ประชากรไทย  ปชท.  #0f41ce
# 2  703      60.0  ความหวังใหม่  ควม.  #e6b750
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1  https://cdn.ectreport.com/images/logos/ประชากร...
# 2  https://cdn.ectreport.com/images/logos/ความหวั...

# %%
# ชื่อ ส.ส.เขต (6)
Candidate_constituency.head(3)
# Out:
#   mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0   ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2  ACR_1_11     นายการันต์ ลุนพันธ์         11              712
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# 1  https://cdn.ectreport.com/images/mp_candidates...
# 2  https://cdn.ectreport.com/images/mp_candidates...

# %%
# ชื่อ จังหวัด (7)
info_province.head(3)
# Out:
#    province_id prov_id         province                       eng abbre_thai  \
# 0           37     ACR       อำนาจเจริญ             AMNAT CHAROEN         อจ
# 1           15     ATG          อ่างทอง                 ANG THONG         อท
# 2           14     AYA  พระนครศรีอยุธยา  PHRA NAKHON SI AYUTTHAYA         อย
#
#    total_registered_vote  total_vote_stations
# 0                 301354                  641
# 1                 224656                  492
# 2                 664431                 1060

# %% [markdown]
# ## Merge Table

# %%
# (3) x (6)
table_merge = result_constituencies_Candidate.merge(Candidate_constituency, how ='left', left_on='mp_app_id',right_on='mp_app_id')
print(table_merge.shape)
table_merge.head()
# Out:
# (4781, 10)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# 1  https://cdn.ectreport.com/images/mp_candidates...
# ...

# %%
# table_merge x (5)
table_merge1 = table_merge.merge(info_party_overview, how ='left', left_on='party_id',right_on='id')
print(table_merge1.shape)
table_merge1.head()
# Out:
# (4781, 16)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url   id  party_no  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  706      14.0
# ...

# %%
# table_merge1 x (4)
table_merge2 = table_merge1.merge(result_constituencies_status, how ='left', left_on='cons_id',right_on='cons_id')
print(table_merge2.shape)
table_merge2.head()
# Out:
# (4781, 22)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...             name  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...    ชาติพัฒนากล้า
# ...

# %%
# table_merge2 x (7)
table_merge3 = table_merge2.merge(info_province, how ='left', left_on='prov_id',right_on='prov_id')
print(table_merge3.shape)
table_merge3.head()
# Out:
# (4781, 28)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761
#
#               mp_app_name  mp_app_no  mp_app_party_id  \
# 0   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1  นางสุขสมรวย วันทนียกุล         10              709
# 2     นายการันต์ ลุนพันธ์         11              712
# 3          นายไสว ผลาวงศ์         12              742
# 4        นายสงบ โสภิพันธ์         13              761
#
#                                            image_url  ...  percent_turn_out  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  ...          72.60136
# ...

# %%
## เขตการเลือกตั้ง
cons_id = table_merge3['cons_id'].tolist()
cons_no = []
for i in range(len(cons_id)):
  re = cons_id[i].split('_')[-1]
  cons_no.append(re)
table_merge3['cons_no'] = cons_no

# %%
table_merge3.head(-10)
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 2      ACR_1  ACR_1_11           13          126              0.11935
# 3      ACR_1  ACR_1_12           12          127              0.12029
# 4      ACR_1  ACR_1_13           11          212              0.20081
# ...      ...       ...          ...          ...                  ...
# 4766   YST_2   YST_2_6            1        44851             45.56547
# 4767   YST_2   YST_2_7            8          301              0.30579
# 4768   YST_2   YST_2_8            9          277              0.28141
# 4769   YST_2   YST_2_9            2        34581             35.13187
# 4770   YST_3   YST_3_1           10          498              0.47641
#
#       party_id             mp_app_name  mp_app_no  mp_app_party_id  \
# ...

# %%
print(table_merge3.isnull().any())
# Out:
# cons_id                  False
# mp_app_id                False
# mp_app_rank              False
# mp_app_vote              False
# mp_app_vote_percent      False
# party_id                 False
# mp_app_name              False
# mp_app_no                False
# mp_app_party_id          False
# image_url                False
# id                       False
# party_no                 False
# name                     False
# abbr                     False
# color                    False
# logo_url                 False
# prov_id                  False
# turn_out                 False
# percent_turn_out         False
# counted_vote_stations    False
# percent_count            False
# pause_report             False
# province_id              False
# province                 False
# eng                      False
# abbre_thai               False
# total_registered_vote    False
# total_vote_stations      False
# cons_no                  False
# dtype: bool

# %%
table_merge3.to_csv('table_merge_result.csv', index=False)

# %% [markdown]
# #🔗Visualize

# %% [markdown]
# #1.จังหวัดใด ในภาคตะวันออกเฉียงเหนือมีจำนวนผู้มาใช้สิทธิ์เลือกตั้ง มากที่สุด 5 อันดับสูงสุด

# %%
ect_66
# Out:
#                            info_province              province_id   string  \
# 0                          info_province                  prov_id   string
# 1                          info_province                 province   string
# 2                          info_province               abbre_thai   string
# 3                          info_province                      eng   string
# 4                          info_province      total_vote_stations   number
# 5                          info_province    total_registered_vote   number
# 6           result_constituencies_status                  prov_id   string
# 7           result_constituencies_status                  cons_id   string
# 8           result_constituencies_status                 turn_out   number
# 9           result_constituencies_status         percent_turn_out   number
# 10          result_constituencies_status    counted_vote_stations   number
# ...

# %%
info_province
# Out:
#     province_id prov_id         province                       eng abbre_thai  \
# 0            37     ACR       อำนาจเจริญ             AMNAT CHAROEN         อจ
# 1            15     ATG          อ่างทอง                 ANG THONG         อท
# 2            14     AYA  พระนครศรีอยุธยา  PHRA NAKHON SI AYUTTHAYA         อย
# 3            10     BKK    กรุงเทพมหานคร                   BANGKOK        กทม
# 4            38     BKN           บึงกาฬ                 BUENG KAN         บก
# ..          ...     ...              ...                       ...        ...
# 72           41     UDN         อุดรธานี                UDON THANI         อด
# 73           61     UTI        อุทัยธานี               UTHAI THANI         อน
# 74           53     UTT        อุตรดิตถ์                 UTTARADIT         อต
# 75           95     YLA             ยะลา                      YALA         ยล
# 76           35     YST            ยโสธร                  YASOTHON         ยส
#
# ...

# %%
result_constituencies_status
# Out:
#     prov_id cons_id  turn_out  percent_turn_out  counted_vote_stations  \
# 0       ACR   ACR_1    105574          72.60136                    310
# 1       ACR   ACR_2    111813          71.70350                    331
# 2       ATG   ATG_1     89756          80.19872                    239
# 3       ATG   ATG_2     91466          81.13075                    253
# 4       AYA   AYA_1    110317          79.55591                    226
# ..      ...     ...       ...               ...                    ...
# 395     YLA   YLA_2    100319          77.61325                    192
# 396     YLA   YLA_3     97956          76.86019                    217
# 397     YST   YST_1    110491          76.24854                    300
# 398     YST   YST_2     98432          69.36569                    302
# 399     YST   YST_3    104532          71.56785                    303
#
#      percent_count  pause_report
# 0            100.0         False
# 1            100.0         False
# ...

# %%
df1 =result_constituencies_status [['prov_id', 'turn_out']]

# %%
df1
# Out:
#     prov_id  turn_out
# 0       ACR    105574
# 1       ACR    111813
# 2       ATG     89756
# 3       ATG     91466
# 4       AYA    110317
# ..      ...       ...
# 395     YLA    100319
# 396     YLA     97956
# 397     YST    110491
# 398     YST     98432
# 399     YST    104532
#
# [400 rows x 2 columns]

# %%
df2 = df1.groupby('prov_id').sum().reset_index() # ทำการ Sum  'prov_id' ให้ตัวที่เหมือนกัน เช่น  ACR+ ACR จังหวัดเดียวกันเข้าด้วยกัน

# %%
df2
# Out:
#    prov_id  turn_out
# 0      ACR    217387
# 1      ATG    181222
# 2      AYA    546346
# 3      BKK   3306641
# 4      BKN    231751
# ..     ...       ...
# 72     UDN    842344
# 73     UTI    185945
# 74     UTT    272802
# 75     YLA    297503
# 76     YST    313455
#
# [77 rows x 2 columns]

# %%
table_merge_prov = info_province.merge(df2 , how ='left', left_on='prov_id',right_on='prov_id')
print(table_merge_prov.shape)
table_merge_prov # นำตาราง info_province และ result_constituencies_status มาต่อกัน
# Out:
# (77, 8)
#     province_id prov_id         province                       eng abbre_thai  \
# 0            37     ACR       อำนาจเจริญ             AMNAT CHAROEN         อจ
# 1            15     ATG          อ่างทอง                 ANG THONG         อท
# 2            14     AYA  พระนครศรีอยุธยา  PHRA NAKHON SI AYUTTHAYA         อย
# 3            10     BKK    กรุงเทพมหานคร                   BANGKOK        กทม
# 4            38     BKN           บึงกาฬ                 BUENG KAN         บก
# ..          ...     ...              ...                       ...        ...
# 72           41     UDN         อุดรธานี                UDON THANI         อด
# 73           61     UTI        อุทัยธานี               UTHAI THANI         อน
# 74           53     UTT        อุตรดิตถ์                 UTTARADIT         อต
# 75           95     YLA             ยะลา                      YALA         ยล
# 76           35     YST            ยโสธร                  YASOTHON         ยส
#
# ...

# %%
Top5_sum_of_turnout = table_merge_prov.sort_values(by='turn_out',ascending=False).head(5)

# %%
Top5_sum_of_turnout
# Out:
#     province_id prov_id       province                eng abbre_thai  \
# 3            10     BKK  กรุงเทพมหานคร            BANGKOK        กทม
# 30           30     NMA     นครราชสีมา  NAKHON RATCHASIMA         นม
# 8            50     CMI      เชียงใหม่         CHIANG MAI         ชม
# 71           34     UBN    อุบลราชธานี   UBON RATCHATHANI         อบ
# 15           40     KKN        ขอนแก่น          KHON KAEN         ขก
#
#     total_registered_vote  total_vote_stations  turn_out
# 3                 4479155                 6360   3306641
# 30                2120399                 4487   1617061
# 8                 1331007                 2615   1088305
# 71                1473971                 3027   1069575
# 15                1449595                 2679   1051368

# %% [markdown]
# #2.จำนวน สส.บัญชีรายชื่อและสส.เขต 5 อันดับแรก

# %%
# Table 1 ส.ส. เขต
Candidate_constituency
# Out:
#      mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0      ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1     ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2     ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3     ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4     ACR_1_13        นายสงบ โสภิพันธ์         13              761
# ...        ...                     ...        ...              ...
# 4776   YST_3_5       นายธนพัฒน์ ศรีชนะ          5              709
# 4777   YST_3_6        นายพิทยา พาลุสุข          6              763
# 4778   YST_3_7      นายศรายุทธ สุดสวาท          7              712
# 4779   YST_3_8    นางสาวสุนันทา สีชมภู          8              769
# 4780   YST_3_9        นายณัฐพล ศรีอุบล          9              726
#
#                                               image_url
# 0     https://cdn.ectreport.com/images/mp_candidates...
# ...

# %%
# จำนวนคะแนนเสียง ส.ส. เขตที่ได้ - mp_app_vot
result_constituencies_Candidate
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 2      ACR_1  ACR_1_11           13          126              0.11935
# 3      ACR_1  ACR_1_12           12          127              0.12029
# 4      ACR_1  ACR_1_13           11          212              0.20081
# ...      ...       ...          ...          ...                  ...
# 4776   YST_3   YST_3_5            1        37946             36.30085
# 4777   YST_3   YST_3_6            7          821              0.78541
# 4778   YST_3   YST_3_7            9          531              0.50798
# 4779   YST_3   YST_3_8           11          296              0.28317
# 4780   YST_3   YST_3_9            3        14502             13.87326
#
#       party_id
# 0          706
# 1          709
# 2          712
# 3          742
# 4          761
# ...        ...
# ...

# %%
# เชื่อมตารางเพื่อ keep ข้อมูลชื่อ สส และ ชื่อ พรรคที่สังกัด
result_constituencies_Candidate['mp_app_name'] = result_constituencies_Candidate['mp_app_id'].map(Candidate_constituency.set_index('mp_app_id')['mp_app_name'])
result_constituencies_Candidate['party_name'] = result_constituencies_Candidate['party_id'].map(info_party_overview.set_index('id')['name'])

# %%
table_cons = result_constituencies_Candidate.sort_values(by=['cons_id', 'mp_app_vote_percent'], ascending=False).reset_index()
table_cons
# Out:
#       index cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      4776   YST_3   YST_3_5            1        37946             36.30085
# 1      4773   YST_3   YST_3_2            2        25205             24.11223
# 2      4780   YST_3   YST_3_9            3        14502             13.87326
# 3      4771   YST_3  YST_3_10            4        13483             12.89844
# 4      4775   YST_3   YST_3_4            5         4957              4.74209
# ...     ...     ...       ...          ...          ...                  ...
# 4776      0   ACR_1   ACR_1_1            9          459              0.43477
# 4777      5   ACR_1   ACR_1_2           10          234              0.22165
# 4778      4   ACR_1  ACR_1_13           11          212              0.20081
# 4779      3   ACR_1  ACR_1_12           12          127              0.12029
# 4780      2   ACR_1  ACR_1_11           13          126              0.11935
#
# ...

# %%
cons_id = list(set(table['cons_id']))
table_cons = pd.DataFrame()
for i in range(len(cons_id)):
  df = result_constituencies_Candidate[result_constituencies_Candidate['cons_id'] == cons_id[i]]
  df = df.sort_values(by='mp_app_vote', ascending=False)[['cons_id', 'mp_app_name', 'mp_app_rank', 'party_name', 'mp_app_vote_percent', 'mp_app_vote']].iloc[0:1]
  table_cons = table_cons.append(df)
# Out:
# <ipython-input-111-826fe08cbd58>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table_cons = table_cons.append(df)
# <ipython-input-111-826fe08cbd58>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table_cons = table_cons.append(df)
# <ipython-input-111-826fe08cbd58>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table_cons = table_cons.append(df)
# <ipython-input-111-826fe08cbd58>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table_cons = table_cons.append(df)
# ...

# %%
table_cons.sort_values(by='mp_app_vote', ascending=False).iloc[0:10] # คะแนนเลือกตั้ง ส.ส. เขต มากที่สุด 10 อันดับแรก
# Out:
#      cons_id                mp_app_name  mp_app_rank      party_name  \
# 4301   TRG_2             นายทวี สุระบาล            1    พลังประชารัฐ
# 4358  UBN_10       นายสมศักดิ์ บุญประชม            1  เพื่อไทรวมพลัง
# 960    CMI_4     นางสาวพุธิตา ชัยอนันต์            1         ก้าวไกล
# 1077   CPM_2      นายเชิงชาย ชาลีรินทร์            1        เพื่อไทย
# 3335   RET_5      นางสาวจิราพร สินธุไพร            1        เพื่อไทย
# 2171  NMA_11  นายอาทิตย์ หวังศุภกิจโกศล            1        เพื่อไทย
# 3910   SPK_5          นางสาวนิตยา มีศรี            1         ก้าวไกล
# 1741   LPN_1  นายวิทวิสิทธิ์ ปันสวนปลูก            1         ก้าวไกล
# 1962   NAN_2          นายชลน่าน ศรีแก้ว            1        เพื่อไทย
# 1579   KSN_1        นายวิรัช พิมพะนิตย์            1        เพื่อไทย
#
#       mp_app_vote_percent  mp_app_vote
# 4301             60.29103        63185
# 4358             62.27446        63127
# 960              54.01387        62009
# 1077             63.43832        61414
# ...

# %%
# จำนวนรวม ส.ส.เขต แต่ละพรรค
table_cons_rank = table_cons.groupby('party_name').agg({'mp_app_rank': 'sum'}).reset_index()
table_cons_rank
# Out:
#          party_name  mp_app_rank
# 0           ก้าวไกล          113
# 1     ชาติพัฒนากล้า            1
# 2      ชาติไทยพัฒนา            9
# 3         ประชาชาติ            7
# 4      ประชาธิปัตย์           22
# 5      พลังประชารัฐ           39
# 6         ภูมิใจไทย           67
# 7   รวมไทยสร้างชาติ           23
# 8          เพื่อไทย          112
# 9    เพื่อไทรวมพลัง            2
# 10      ไทยสร้างไทย            5

# %%
# จำนวน ส.ส.เขต แบ่งตามพรรคมากที่สุด 5 อันดับแรก
table_cons_rank.sort_values(by='mp_app_rank', ascending=False).iloc[0:5]
# Out:
#         party_name  mp_app_rank
# 0          ก้าวไกล          113
# 8         เพื่อไทย          112
# 6        ภูมิใจไทย           67
# 5     พลังประชารัฐ           39
# 7  รวมไทยสร้างชาติ           23

# %%
# Table 2 สส.บัญชีรายชื่อ
Candidate_partyList
# Out:
#       party_no  list_no                    name  \
# 0            1        1   นายกฤดิทัช แสงธนโยธิน
# 1            1        2     นายสุปรีย์ แสงสว่าง
# 2            1        3     นายธนภัท อุทุมพันธ์
# 3            1        4          นายทิวา ขำศิริ
# 4            1        5  นายปิยพัชร์ อ่ำสำอางค์
# ...        ...      ...                     ...
# 1893        67       23        นายบุญมี ขวัญยืน
# 1894        67       24       นายบุญธรรม จองนาง
# 1895        67       25      นางยุพิน เผ็งบุญมา
# 1896        67       26       นางวรนุช เรียนเวช
# 1897        67       27    นางทัศนีญ์ ศรีไชยวาน
#
#                                               image_url
# 0     https://cdn.ectreport.com/images/candidates/นา...
# 1     https://cdn.ectreport.com/images/candidates/นา...
# 2     https://cdn.ectreport.com/images/candidates/นา...
# 3     https://cdn.ectreport.com/images/candidates/นา...
# 4     https://cdn.ectreport.com/images/candidates/นา...
# ...

# %%
# จำนวนคะแนนเสียง ส.ส. บัญชีรายชื่อของพรรคนั้น - party_list_vote
result_constituencies_PartyList
# Out:
#       cons_id  party_id  party_list_vote  party_list_vote_percent
# 0       ACR_1       701             4550                  4.30977
# 1       ACR_1       702              185                  0.17523
# 2       ACR_1       703               67                  0.06346
# 3       ACR_1       705            33576                 31.80328
# 4       ACR_1       706              132                  0.12503
# ...       ...       ...              ...                      ...
# 26795   YST_3       780              145                  0.13871
# 26796   YST_3       781              412                  0.39414
# 26797   YST_3       783               17                  0.01626
# 26798   YST_3       784              138                  0.13202
# 26799   YST_3       786               85                  0.08131
#
# [26800 rows x 4 columns]

# %% [markdown]
# #3.จังหวัดใดบ้างที่มีคนเข้าใช้สิทธ์ในการเลือกตั้งน้อยกว่า 40,000 คน

# %%
table_merge_rein = info_province.merge(info_constituency	, how ='left', left_on='prov_id',right_on='prov_id')
print(table_merge_rein.shape)
table_merge_rein
# Out:
# (1136, 12)
#       province_id prov_id    province            eng abbre_thai  \
# 0              37     ACR  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 1              37     ACR  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 2              37     ACR  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 3              37     ACR  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 4              37     ACR  อำนาจเจริญ  AMNAT CHAROEN         อจ
# ...           ...     ...         ...            ...        ...
# 1131           35     YST       ยโสธร       YASOTHON         ยส
# 1132           35     YST       ยโสธร       YASOTHON         ยส
# 1133           35     YST       ยโสธร       YASOTHON         ยส
# 1134           35     YST       ยโสธร       YASOTHON         ยส
# 1135           35     YST       ยโสธร       YASOTHON         ยส
#
#       total_registered_vote  total_vote_stations_x cons_id  cons_no  \
# 0                    301354                    641   ACR_1        1
# ...

# %%
Re_in = table_merge_rein

# %%
a = Re_in.groupby('zone')[['total_registered_vote','registered_vote']].count().reset_index()
a
# Out:
#                                                    zone  \
# 0              อำเภอกงหรา (ยกเว้นตำบลสมหวัง, ตำบลชะรัด)
# 1               อำเภอกงหรา (เฉพาะตำบลสมหวัง, ตำบลชะรัด)
# 2     อำเภอกงไกรลาศ (ยกเว้นตำบลไกรกลาง, ตำบลไกรใน, ต...
# 3     อำเภอกงไกรลาศ (เฉพาะตำบลไกรกลาง, ตำบลไกรใน, ตำ...
# 4                                      อำเภอกบินทร์บุรี
# ...                                                 ...
# 1129                     เขตหนองแขม (ยกเว้นแขวงหนองแขม)
# 1130                      เขตหนองแขม (เฉพาะแขวงหนองแขม)
# 1131                  เขตหลักสี่ (ยกเว้นแขวงตลาดบางเขน)
# 1132                   เขตหลักสี่ (เฉพาะแขวงตลาดบางเขน)
# 1133                                        เขตห้วยขวาง
#
#       total_registered_vote  registered_vote
# 0                         1                1
# 1                         1                1
# 2                         1                1
# 3                         1                1
# 4                         1                1
# ...

# %%
Re_inlow = Re_in[Re_in['total_registered_vote']<(400000)]
Re_inlow
# Out:
#       province_id prov_id    province            eng abbre_thai  \
# 0              37     ACR  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 1              37     ACR  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 2              37     ACR  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 3              37     ACR  อำนาจเจริญ  AMNAT CHAROEN         อจ
# 4              37     ACR  อำนาจเจริญ  AMNAT CHAROEN         อจ
# ...           ...     ...         ...            ...        ...
# 1119           95     YLA        ยะลา           YALA         ยล
# 1120           95     YLA        ยะลา           YALA         ยล
# 1121           95     YLA        ยะลา           YALA         ยล
# 1122           95     YLA        ยะลา           YALA         ยล
# 1123           95     YLA        ยะลา           YALA         ยล
#
#       total_registered_vote  total_vote_stations_x cons_id  cons_no  \
# 0                    301354                    641   ACR_1        1
# ...

# %%
Re_in.isnull().any()
# Out:
# province_id              False
# prov_id                  False
# province                 False
# eng                      False
# abbre_thai               False
# total_registered_vote    False
# total_vote_stations_x    False
# cons_id                  False
# cons_no                  False
# registered_vote          False
# total_vote_stations_y    False
# zone                     False
# dtype: bool

# %%
Re_inlow.count()
# Out:
# province_id              173
# prov_id                  173
# province                 173
# eng                      173
# abbre_thai               173
# total_registered_vote    173
# total_vote_stations_x    173
# cons_id                  173
# cons_no                  173
# registered_vote          173
# total_vote_stations_y    173
# zone                     173
# dtype: int64

# %% [markdown]
# ###ans 3

# %%
print('จังหวัดที่มีคนเข้าใช้สิทธ์ในการเลือกตั้งน้อยกว่า 40,000 คน มี54จังหวัด')
# Out:
# จังหวัดที่มีคนเข้าใช้สิทธ์ในการเลือกตั้งน้อยกว่า 40,000 คน มี54จังหวัด

# %% [markdown]
# #4.พรรคการเมืองใด ที่ได้รับอันดับคะแนนรวมต่ำสุด 5 อันดับ

# %%
# Table 1 พรรคที่สังกัด
info_party_overview.head()
# Out:
#     id  party_no           name  abbr    color  \
# 0  701      26.0   ประชาธิปัตย์  ปชป.  #06aff3
# 1  702      63.0     ประชากรไทย  ปชท.  #0f41ce
# 2  703      60.0   ความหวังใหม่  ควม.  #e6b750
# 3  705      29.0       เพื่อไทย   พท.  #da3731
# 4  706      14.0  ชาติพัฒนากล้า  ชพก.  #233e8a
#
#                                             logo_url
# 0  https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1  https://cdn.ectreport.com/images/logos/ประชากร...
# 2  https://cdn.ectreport.com/images/logos/ความหวั...
# 3  https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4  https://cdn.ectreport.com/images/logos/ชาติพัฒ...

# %%
# Table 2 คะแนนเลือกตั้ง ----------------------------------------main
result_constituencies_Candidate.head()
# Out:
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0   ACR_1   ACR_1_1            9          459              0.43477       706
# 1   ACR_1  ACR_1_10            1        38275             36.25419       709
# 2   ACR_1  ACR_1_11           13          126              0.11935       712
# 3   ACR_1  ACR_1_12           12          127              0.12029       742
# 4   ACR_1  ACR_1_13           11          212              0.20081       761

# %%
#(1)x(2)
sumvote_party = info_party_overview.merge(result_constituencies_Candidate	, how ='left', left_on='id',right_on='party_id')
print(sumvote_party.shape)
sumvote_party
# Out:
# (4781, 12)
#        id  party_no          name  abbr    color  \
# 0     701      26.0  ประชาธิปัตย์  ปชป.  #06aff3
# 1     701      26.0  ประชาธิปัตย์  ปชป.  #06aff3
# 2     701      26.0  ประชาธิปัตย์  ปชป.  #06aff3
# 3     701      26.0  ประชาธิปัตย์  ปชป.  #06aff3
# 4     701      26.0  ประชาธิปัตย์  ปชป.  #06aff3
# ...   ...       ...           ...   ...      ...
# 4776  786      20.0       เปลี่ยน    ป.  #cc898a
# 4777  786      20.0       เปลี่ยน    ป.  #cc898a
# 4778  786      20.0       เปลี่ยน    ป.  #cc898a
# 4779  786      20.0       เปลี่ยน    ป.  #cc898a
# 4780  786      20.0       เปลี่ยน    ป.  #cc898a
#
#                                                logo_url cons_id mp_app_id  \
# 0     https://cdn.ectreport.com/images/logos/ประชาธิ...   ACR_1   ACR_1_5
# 1     https://cdn.ectreport.com/images/logos/ประชาธิ...   ACR_2   ACR_2_5
# 2     https://cdn.ectreport.com/images/logos/ประชาธิ...   ATG_1   ATG_1_4
# ...

# %%
sumvote_party.groupby('name')[['party_no','mp_app_vote']].max().reset_index().sort_values(by='mp_app_vote',ascending=False).head(5)  # ,ascending=False เรียงมากไปน้อย
# Out:
#               name  party_no  mp_app_vote
# 23    พลังประชารัฐ      37.0        63185
# 52  เพื่อไทรวมพลัง      38.0        63127
# 1          ก้าวไกล      31.0        62009
# 51        เพื่อไทย      29.0        61414
# 7     ชาติไทยพัฒนา      18.0        55877

# %% [markdown]
# #5.จำนวนผู้สมัครแต่ละพรรค
#
# 1.   รายการในลิสต์
# 2.   รายการในลิสต์
